# %%
import os
import gc
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, cohen_kappa_score
import tensorflow as tf
# 001
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, ResNet50, DenseNet121, InceptionV3, EfficientNetB0, Xception, MobileNetV2
from tensorflow.keras import models, layers, optimizers, callbacks
from tensorflow.keras import backend as K

# 002
# from keras._tf_keras.keras.preprocessing.image import  ImageDataGenerator
# from keras._tf_keras.keras.applications import VGG16, ResNet50, DenseNet121, InceptionV3, EfficientNetB0, Xception, MobileNetV2
# from keras._tf_keras.keras import models, layers, optimizers, callbacks
# from keras._tf_keras.keras import backend as K


print("Todas as bibliotecas foram importadas com sucesso!")
# Out:
# Todas as bibliotecas foram importadas com sucesso!

# %%
# Criando função para calcular as métricas

def get_metrics(y_true, y_pred):
    vn, fp, fn, vp = confusion_matrix(y_true, y_pred).ravel()
    accuracy = (vp + vn) / (vp + fp + fn + vn)  
    recall = vp / (vp + fn)
    specificity = vn / (vn + fp)
    precision = vp / (vp + fp)
    f1 = f1_score(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)
    auc_roc = roc_auc_score(y_true, y_pred)

    return {
        'accuracy': accuracy,
        'specificity': specificity,
        'recall': recall,
        'precision': precision,
        'f1-score': f1,
        'kappa': kappa,
        'auc-roc': auc_roc
    }

# %%
# Criando função para seleção de esquema de cor 
def convert_color_scale(image, scale):
    if scale == 'hsv':
        return cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    elif scale == 'rgb':
        return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    elif scale == 'grayscale':
        # Converter para escala de cinza e replicar para 3 canais
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        return cv2.merge([gray, gray, gray])
    elif scale == 'lab':
        return cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    elif scale == 'luv':
        return cv2.cvtColor(image, cv2.COLOR_BGR2LUV)
    elif scale == 'xyz':
        return cv2.cvtColor(image, cv2.COLOR_BGR2XYZ)
    else:
        raise ValueError("Escala de cor não suportada.")

# %%
# Carregamento e pré-processamento de imagens com escolha de escala de cor

def load_images(folder, color_scale, img_extensions):
    images = []
    for filename in os.listdir(folder):
        if any(filename.lower().endswith(ext) for ext in img_extensions):
            img_path = os.path.join(folder, filename)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, (224, 224))  # Ajuste o tamanho conforme necessário
                img = convert_color_scale(img, color_scale)  # Converta para a escala de cor desejada
                # Se a imagem estiver em escala de cinza, expanda as dimensões
                if color_scale == 'grayscale':
                    img = np.expand_dims(img, axis=-1)  # Adiciona uma dimensão de canal
                images.append(img)

    return np.array(images)

# %%
# Defina as pastas de dados
data_dir = r"C:\Users\andre\Downloads\archive\OvarianCancer\\duas"
normal_dir = os.path.join(data_dir, 'Non_Cancerous')
cancer_dir = os.path.join(data_dir, 'Endometri')
img_extensions = ['.jpg', '.jpeg', '.png']

if os.path.exists(normal_dir): print(f"Pasta normal_dir acessada com sucesso.") 
else: print(f"Erro ao acessar a pasta normal_dir.") 
if os.path.exists(cancer_dir): print(f"Pasta cancer_dir acessada com sucesso.") 
else: print(f"Erro ao acessar a pasta cancer_dir.")

if os.listdir(normal_dir):print("sim, na pasta normal ha itens")
if os.listdir(cancer_dir):print("sim, na pasta cancer ha itens")
# Out:
# Pasta normal_dir acessada com sucesso.
# Pasta cancer_dir acessada com sucesso.
# sim, na pasta normal ha itens
# sim, na pasta cancer ha itens

# %%
# Criar um DataFrame para armazenar os resultados
columns = ['Modelo', 'Acuracia', 'Sensibilidade', 'Especificidade', 'F-Score', 'AUC-ROC']
df_metrics = pd.DataFrame(columns=columns)

# Definir o caminho para salvar o melhor modelo
model_checkpoint_path = r"C:\Users\andre\Documents\atividades\estudos_opencv\processamento de imagens\\best_model.h5"

# %%
# Iterar sobre os modelos
def model_execution(model_name):

    # Carregamento de imagens e conversão para XYZ
    normal_images = load_images(normal_dir, 'rgb',img_extensions)
    cancer_images = load_images(cancer_dir, 'rgb',img_extensions)

    # Rótulos para imagens (0 para normal, 1 para câncer)
    normal_labels = np.zeros(normal_images.shape[0])
    cancer_labels = np.ones(cancer_images.shape[0])

    # Concatenar imagens e rótulos
    all_images = np.concatenate([normal_images, cancer_images], axis=0)
    all_labels = np.concatenate([normal_labels, cancer_labels], axis=0)

    # Dividir o conjunto de dados em treino e teste (80/20)
    X_train, X_test, y_train, y_test = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)

    # Escolha entre 5 tipos de conversão de escala de cor aqui (por exemplo, normalização)
    X_train = X_train / 255.0
    X_test = X_test / 255.0

    # Escolher o modelo de CNN
    if model_name == 'VGG16':
        base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'ResNet50':
        base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'MobileNetV2':
        base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'InceptionV3':
        base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'EfficientNetB0':
        base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'Xception':
        base_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'VisionTransformer':
            base_model = VitB16(image_size=(224, 224), weights='imagenet', include_top=False)
    else:
        raise ValueError("Modelo de CNN não suportado.")

    # Construir o modelo
    model = models.Sequential()
    model.add(base_model)
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))

    # Compilar o modelo
    model.compile(optimizer=optimizers.Adam(learning_rate=1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Configurar o retorno de chamada ModelCheckpoint
#     checkpoint = callbacks.ModelCheckpoint(model_checkpoint_path,
#                                            monitor='val_accuracy',  # Métrica a ser monitorad
#                                            mode='max',               # Salvar o modelo com a maior precisão
#                                            verbose=1)

    # Treinar o modelo
    model.fit(X_train, y_train, epochs=60, batch_size=16, validation_split=0.2)

    # Avaliar o modelo
    y_pred = model.predict(X_test)
    y_pred_binary = (y_pred > 0.5).astype(int)

    # Calcular métricas
    metrics = get_metrics(y_test, y_pred_binary)

    # Adicionar as métricas ao DataFrame
    metrics['Modelo'] = model_name
    
    # Excluir o modelo atual para liberar memória da GPU   
    del all_images, normal_images, cancer_images, X_train, X_test, y_train, y_test, y_pred, y_pred_binary
    del all_labels, normal_labels, cancer_labels
    tf.keras.backend.clear_session()
    del model, base_model
    gc.collect()
    
    return metrics

# %%
chosen_model = 'VGG16'
metrics = model_execution(chosen_model)
metrics = model_execution(chosen_model)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics = pd.concat([df_metrics, temp_df], ignore_index=True)

chosen_model = 'ResNet50'
metrics = model_execution(chosen_model)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics = pd.concat([df_metrics, temp_df], ignore_index=True)

chosen_model = 'InceptionV3'
metrics = model_execution(chosen_model)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics = pd.concat([df_metrics, temp_df], ignore_index=True)

chosen_model = 'MobileNetV2'
metrics = model_execution(chosen_model)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics = pd.concat([df_metrics, temp_df], ignore_index=True)

chosen_model = 'EfficientNetB0'
metrics = model_execution(chosen_model)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics = pd.concat([df_metrics, temp_df], ignore_index=True)

df_metrics
# Out:
# Epoch 1/60
# 8/8 [==============================] - 2s 159ms/step - loss: 0.6971 - accuracy: 0.6000 - val_loss: 0.6732 - val_accuracy: 0.5625
# Epoch 2/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.6657 - accuracy: 0.5440 - val_loss: 0.6144 - val_accuracy: 0.7188
# Epoch 3/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.6309 - accuracy: 0.6560 - val_loss: 0.5967 - val_accuracy: 0.7500
# Epoch 4/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.5099 - accuracy: 0.7280 - val_loss: 0.4759 - val_accuracy: 0.7812
# Epoch 5/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.5121 - accuracy: 0.7360 - val_loss: 0.5131 - val_accuracy: 0.7500
# Epoch 6/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.2600 - accuracy: 0.8880 - val_loss: 0.5208 - val_accuracy: 0.6562
# Epoch 7/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.1833 - accuracy: 0.9600 - val_loss: 0.4216 - val_accuracy: 0.8125
# Epoch 8/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.3369 - accuracy: 0.8720 - val_loss: 0.3569 - val_accuracy: 0.8125
# Epoch 9/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.1947 - accuracy: 0.9120 - val_loss: 0.3978 - val_accuracy: 0.8125
# Epoch 10/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.1707 - accuracy: 0.9440 - val_loss: 0.4317 - val_accuracy: 0.8750
# Epoch 11/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.1293 - accuracy: 0.9360 - val_loss: 0.7292 - val_accuracy: 0.9375
# Epoch 12/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0658 - accuracy: 0.9840 - val_loss: 0.4807 - val_accuracy: 0.8750
# Epoch 13/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0346 - accuracy: 0.9920 - val_loss: 0.3073 - val_accuracy: 0.9062
# Epoch 14/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0312 - accuracy: 0.9840 - val_loss: 0.2256 - val_accuracy: 0.9375
# Epoch 15/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0354 - accuracy: 0.9840 - val_loss: 0.9763 - val_accuracy: 0.7188
# Epoch 16/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.1987 - accuracy: 0.9280 - val_loss: 0.5123 - val_accuracy: 0.8750
# Epoch 17/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0861 - accuracy: 0.9680 - val_loss: 0.4906 - val_accuracy: 0.9375
# Epoch 18/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0164 - accuracy: 0.9920 - val_loss: 0.5118 - val_accuracy: 0.9375
# Epoch 19/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5512 - val_accuracy: 0.8750
# Epoch 20/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0224 - accuracy: 0.9840 - val_loss: 1.1086 - val_accuracy: 0.9062
# Epoch 21/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.9271 - val_accuracy: 0.9375
# Epoch 22/60
# 8/8 [==============================] - 1s 137ms/step - loss: 3.9707e-04 - accuracy: 1.0000 - val_loss: 0.8680 - val_accuracy: 0.9375
# Epoch 23/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0120 - accuracy: 0.9920 - val_loss: 1.1918 - val_accuracy: 0.8750
# Epoch 24/60
# 8/8 [==============================] - 1s 138ms/step - loss: 9.5681e-04 - accuracy: 1.0000 - val_loss: 1.4569 - val_accuracy: 0.9062
# Epoch 25/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.2977 - val_accuracy: 0.8750
# Epoch 26/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 2.2547 - val_accuracy: 0.7812
# Epoch 27/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.1109 - accuracy: 0.9520 - val_loss: 2.0890 - val_accuracy: 0.6562
# Epoch 28/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.2721 - accuracy: 0.9520 - val_loss: 0.9683 - val_accuracy: 0.8438
# Epoch 29/60
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0527 - accuracy: 0.9840 - val_loss: 1.0182 - val_accuracy: 0.7812
# Epoch 30/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.8933 - val_accuracy: 0.8125
# Epoch 31/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0809 - accuracy: 0.9680 - val_loss: 0.4974 - val_accuracy: 0.8750
# Epoch 32/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.1161 - accuracy: 0.9760 - val_loss: 0.5055 - val_accuracy: 0.8750
# Epoch 33/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.9567 - val_accuracy: 0.9062
# Epoch 34/60
# 8/8 [==============================] - 1s 138ms/step - loss: 5.1071e-04 - accuracy: 1.0000 - val_loss: 1.3894 - val_accuracy: 0.9062
# Epoch 35/60
# 8/8 [==============================] - 1s 137ms/step - loss: 3.8445e-04 - accuracy: 1.0000 - val_loss: 1.4608 - val_accuracy: 0.8750
# Epoch 36/60
# 8/8 [==============================] - 1s 138ms/step - loss: 1.1504e-05 - accuracy: 1.0000 - val_loss: 1.1964 - val_accuracy: 0.9062
# Epoch 37/60
# 8/8 [==============================] - 1s 137ms/step - loss: 1.6715e-05 - accuracy: 1.0000 - val_loss: 1.1940 - val_accuracy: 0.9062
# Epoch 38/60
# 8/8 [==============================] - 1s 138ms/step - loss: 4.7468e-04 - accuracy: 1.0000 - val_loss: 1.4757 - val_accuracy: 0.9062
# Epoch 39/60
# 8/8 [==============================] - 1s 137ms/step - loss: 1.5024e-05 - accuracy: 1.0000 - val_loss: 1.6986 - val_accuracy: 0.9062
# Epoch 40/60
# 8/8 [==============================] - 1s 138ms/step - loss: 6.5571e-05 - accuracy: 1.0000 - val_loss: 1.6645 - val_accuracy: 0.9062
# Epoch 41/60
# 8/8 [==============================] - 1s 138ms/step - loss: 1.9536e-04 - accuracy: 1.0000 - val_loss: 1.4984 - val_accuracy: 0.9062
# Epoch 42/60
# 8/8 [==============================] - 1s 137ms/step - loss: 1.9149e-04 - accuracy: 1.0000 - val_loss: 1.4422 - val_accuracy: 0.9062
# Epoch 43/60
# 8/8 [==============================] - 1s 137ms/step - loss: 2.6340e-07 - accuracy: 1.0000 - val_loss: 1.4479 - val_accuracy: 0.9375
# Epoch 44/60
# 8/8 [==============================] - 1s 138ms/step - loss: 3.1335e-07 - accuracy: 1.0000 - val_loss: 1.4620 - val_accuracy: 0.9375
# Epoch 45/60
# 8/8 [==============================] - 1s 138ms/step - loss: 2.2026e-06 - accuracy: 1.0000 - val_loss: 1.4693 - val_accuracy: 0.9375
# Epoch 46/60
# 8/8 [==============================] - 1s 138ms/step - loss: 1.3264e-06 - accuracy: 1.0000 - val_loss: 1.4699 - val_accuracy: 0.9375
# Epoch 47/60
# 8/8 [==============================] - 1s 138ms/step - loss: 2.5031e-07 - accuracy: 1.0000 - val_loss: 1.4710 - val_accuracy: 0.9375
# Epoch 48/60
# 8/8 [==============================] - 1s 137ms/step - loss: 1.2809e-06 - accuracy: 1.0000 - val_loss: 1.4733 - val_accuracy: 0.9375
# Epoch 49/60
# 8/8 [==============================] - 1s 138ms/step - loss: 1.3049e-05 - accuracy: 1.0000 - val_loss: 1.4926 - val_accuracy: 0.9375
# Epoch 50/60
# 8/8 [==============================] - 1s 139ms/step - loss: 3.7328e-06 - accuracy: 1.0000 - val_loss: 1.5087 - val_accuracy: 0.9375
# Epoch 51/60
# 8/8 [==============================] - 1s 138ms/step - loss: 1.2161e-05 - accuracy: 1.0000 - val_loss: 1.4930 - val_accuracy: 0.9375
# Epoch 52/60
# 8/8 [==============================] - 1s 137ms/step - loss: 4.2823e-06 - accuracy: 1.0000 - val_loss: 1.4846 - val_accuracy: 0.9375
# Epoch 53/60
# 8/8 [==============================] - 1s 138ms/step - loss: 1.1598e-06 - accuracy: 1.0000 - val_loss: 1.4838 - val_accuracy: 0.9375
# Epoch 54/60
# 8/8 [==============================] - 1s 138ms/step - loss: 4.1468e-05 - accuracy: 1.0000 - val_loss: 1.4756 - val_accuracy: 0.9375
# Epoch 55/60
# 8/8 [==============================] - 1s 138ms/step - loss: 6.5075e-06 - accuracy: 1.0000 - val_loss: 1.5659 - val_accuracy: 0.9375
# Epoch 56/60
# 8/8 [==============================] - 1s 138ms/step - loss: 1.7980e-07 - accuracy: 1.0000 - val_loss: 1.6281 - val_accuracy: 0.9375
# Epoch 57/60
# 8/8 [==============================] - 1s 138ms/step - loss: 3.6438e-07 - accuracy: 1.0000 - val_loss: 1.6548 - val_accuracy: 0.9375
# Epoch 58/60
# 8/8 [==============================] - 1s 138ms/step - loss: 3.1702e-08 - accuracy: 1.0000 - val_loss: 1.6670 - val_accuracy: 0.9375
# Epoch 59/60
# 8/8 [==============================] - 1s 138ms/step - loss: 6.4363e-07 - accuracy: 1.0000 - val_loss: 1.6772 - val_accuracy: 0.9375
# Epoch 60/60
# 8/8 [==============================] - 1s 138ms/step - loss: 1.0568e-07 - accuracy: 1.0000 - val_loss: 1.6798 - val_accuracy: 0.9375
# Epoch 1/60
# 8/8 [==============================] - 2s 155ms/step - loss: 0.8384 - accuracy: 0.5040 - val_loss: 0.8640 - val_accuracy: 0.4375
# Epoch 2/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.6049 - accuracy: 0.6560 - val_loss: 0.4294 - val_accuracy: 0.8750
# Epoch 3/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.3621 - accuracy: 0.8240 - val_loss: 0.4057 - val_accuracy: 0.8438
# Epoch 4/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.1617 - accuracy: 0.9280 - val_loss: 0.4474 - val_accuracy: 0.8438
# Epoch 5/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.1553 - accuracy: 0.9360 - val_loss: 0.4069 - val_accuracy: 0.8125
# Epoch 6/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.1787 - accuracy: 0.9520 - val_loss: 0.8140 - val_accuracy: 0.8750
# Epoch 7/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.0877 - accuracy: 0.9600 - val_loss: 0.4927 - val_accuracy: 0.8438
# Epoch 8/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.1552 - accuracy: 0.9680 - val_loss: 0.4503 - val_accuracy: 0.8750
# Epoch 9/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.1332 - accuracy: 0.9680 - val_loss: 1.4082 - val_accuracy: 0.8438
# Epoch 10/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.1937 - accuracy: 0.9440 - val_loss: 0.7743 - val_accuracy: 0.8750
# Epoch 11/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0664 - accuracy: 0.9680 - val_loss: 0.7268 - val_accuracy: 0.8438
# Epoch 12/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0554 - accuracy: 0.9760 - val_loss: 0.9712 - val_accuracy: 0.9062
# Epoch 13/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0555 - accuracy: 0.9920 - val_loss: 1.4315 - val_accuracy: 0.9062
# Epoch 14/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.3448 - val_accuracy: 0.9062
# Epoch 15/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0633 - accuracy: 0.9840 - val_loss: 1.1139 - val_accuracy: 0.9062
# Epoch 16/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.0140 - accuracy: 0.9920 - val_loss: 1.1662 - val_accuracy: 0.8750
# Epoch 17/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.1598 - accuracy: 0.9520 - val_loss: 0.7572 - val_accuracy: 0.7188
# Epoch 18/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0785 - accuracy: 0.9760 - val_loss: 0.5349 - val_accuracy: 0.7812
# Epoch 19/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0749 - accuracy: 0.9760 - val_loss: 1.1365 - val_accuracy: 0.8125
# Epoch 20/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0661 - accuracy: 0.9760 - val_loss: 1.1598 - val_accuracy: 0.7812
# Epoch 21/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0622 - accuracy: 0.9920 - val_loss: 1.3342 - val_accuracy: 0.9062
# Epoch 22/60
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.4665 - val_accuracy: 0.8438
# Epoch 23/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.2220 - accuracy: 0.9600 - val_loss: 1.1915 - val_accuracy: 0.7812
# Epoch 24/60
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0341 - accuracy: 0.9840 - val_loss: 1.1222 - val_accuracy: 0.8438
# Epoch 25/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.0717 - accuracy: 0.9680 - val_loss: 0.9277 - val_accuracy: 0.9062
# Epoch 26/60
# 8/8 [==============================] - 1s 140ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.9611 - val_accuracy: 0.9062
# Epoch 27/60
# 8/8 [==============================] - 1s 141ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.9303 - val_accuracy: 0.8438
# Epoch 28/60
# 8/8 [==============================] - 1s 141ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.9662 - val_accuracy: 0.8438
# Epoch 29/60
# 8/8 [==============================] - 1s 140ms/step - loss: 3.5897e-04 - accuracy: 1.0000 - val_loss: 0.9945 - val_accuracy: 0.8750
# Epoch 30/60
# 8/8 [==============================] - 1s 139ms/step - loss: 1.2947e-04 - accuracy: 1.0000 - val_loss: 1.0219 - val_accuracy: 0.8750
# Epoch 31/60
# 8/8 [==============================] - 1s 139ms/step - loss: 2.3816e-04 - accuracy: 1.0000 - val_loss: 1.0513 - val_accuracy: 0.8750
# Epoch 32/60
# 8/8 [==============================] - 1s 138ms/step - loss: 3.3739e-04 - accuracy: 1.0000 - val_loss: 1.0829 - val_accuracy: 0.9062
# Epoch 33/60
# 8/8 [==============================] - 1s 139ms/step - loss: 2.0730e-04 - accuracy: 1.0000 - val_loss: 1.0831 - val_accuracy: 0.8750
# Epoch 34/60
# 8/8 [==============================] - 1s 139ms/step - loss: 2.1354e-05 - accuracy: 1.0000 - val_loss: 1.0667 - val_accuracy: 0.8750
# Epoch 35/60
# 8/8 [==============================] - 1s 139ms/step - loss: 3.7094e-05 - accuracy: 1.0000 - val_loss: 1.0613 - val_accuracy: 0.8750
# Epoch 36/60
# 8/8 [==============================] - 1s 139ms/step - loss: 1.9027e-05 - accuracy: 1.0000 - val_loss: 1.0595 - val_accuracy: 0.8750
# Epoch 37/60
# 8/8 [==============================] - 1s 139ms/step - loss: 1.7338e-04 - accuracy: 1.0000 - val_loss: 1.0554 - val_accuracy: 0.8750
# Epoch 38/60
# 8/8 [==============================] - 1s 139ms/step - loss: 1.1405e-05 - accuracy: 1.0000 - val_loss: 1.0405 - val_accuracy: 0.8750
# Epoch 39/60
# 8/8 [==============================] - 1s 139ms/step - loss: 5.6338e-05 - accuracy: 1.0000 - val_loss: 1.0367 - val_accuracy: 0.8750
# Epoch 40/60
# 8/8 [==============================] - 1s 138ms/step - loss: 2.5630e-05 - accuracy: 1.0000 - val_loss: 1.0399 - val_accuracy: 0.8750
# Epoch 41/60
# 8/8 [==============================] - 1s 139ms/step - loss: 3.2077e-05 - accuracy: 1.0000 - val_loss: 1.0440 - val_accuracy: 0.8750
# Epoch 42/60
# 8/8 [==============================] - 1s 139ms/step - loss: 7.7868e-05 - accuracy: 1.0000 - val_loss: 1.0498 - val_accuracy: 0.8750
# Epoch 43/60
# 8/8 [==============================] - 1s 140ms/step - loss: 2.1023e-05 - accuracy: 1.0000 - val_loss: 1.0595 - val_accuracy: 0.8750
# Epoch 44/60
# 8/8 [==============================] - 1s 140ms/step - loss: 7.9783e-05 - accuracy: 1.0000 - val_loss: 1.0688 - val_accuracy: 0.8750
# Epoch 45/60
# 8/8 [==============================] - 1s 139ms/step - loss: 2.0751e-05 - accuracy: 1.0000 - val_loss: 1.0835 - val_accuracy: 0.8750
# Epoch 46/60
# 8/8 [==============================] - 1s 139ms/step - loss: 1.3803e-05 - accuracy: 1.0000 - val_loss: 1.0931 - val_accuracy: 0.8750
# Epoch 47/60
# 8/8 [==============================] - 1s 139ms/step - loss: 1.8584e-05 - accuracy: 1.0000 - val_loss: 1.0999 - val_accuracy: 0.8750
# Epoch 48/60
# 8/8 [==============================] - 1s 139ms/step - loss: 9.3534e-06 - accuracy: 1.0000 - val_loss: 1.1044 - val_accuracy: 0.8750
# Epoch 49/60
# 8/8 [==============================] - 1s 138ms/step - loss: 1.5650e-05 - accuracy: 1.0000 - val_loss: 1.1063 - val_accuracy: 0.8750
# Epoch 50/60
# 8/8 [==============================] - 1s 139ms/step - loss: 2.3612e-06 - accuracy: 1.0000 - val_loss: 1.1063 - val_accuracy: 0.8750
# Epoch 51/60
# 8/8 [==============================] - 1s 139ms/step - loss: 4.8821e-06 - accuracy: 1.0000 - val_loss: 1.1082 - val_accuracy: 0.8750
# Epoch 52/60
# 8/8 [==============================] - 1s 139ms/step - loss: 4.9642e-06 - accuracy: 1.0000 - val_loss: 1.1102 - val_accuracy: 0.8750
# Epoch 53/60
# 8/8 [==============================] - 1s 138ms/step - loss: 6.5758e-06 - accuracy: 1.0000 - val_loss: 1.1121 - val_accuracy: 0.8750
# Epoch 54/60
# 8/8 [==============================] - 1s 139ms/step - loss: 3.5315e-05 - accuracy: 1.0000 - val_loss: 1.1177 - val_accuracy: 0.8750
# Epoch 55/60
# 8/8 [==============================] - 1s 139ms/step - loss: 2.7445e-05 - accuracy: 1.0000 - val_loss: 1.1230 - val_accuracy: 0.8750
# Epoch 56/60
# 8/8 [==============================] - 1s 139ms/step - loss: 9.9496e-07 - accuracy: 1.0000 - val_loss: 1.1269 - val_accuracy: 0.8750
# Epoch 57/60
# 8/8 [==============================] - 1s 140ms/step - loss: 2.3686e-04 - accuracy: 1.0000 - val_loss: 1.1581 - val_accuracy: 0.9062
# Epoch 58/60
# 8/8 [==============================] - 1s 139ms/step - loss: 1.7395e-06 - accuracy: 1.0000 - val_loss: 1.1881 - val_accuracy: 0.9062
# Epoch 59/60
# 8/8 [==============================] - 1s 139ms/step - loss: 1.4072e-05 - accuracy: 1.0000 - val_loss: 1.2035 - val_accuracy: 0.9062
# Epoch 60/60
# 8/8 [==============================] - 1s 139ms/step - loss: 6.7896e-06 - accuracy: 1.0000 - val_loss: 1.2101 - val_accuracy: 0.9062
# Epoch 1/60
# 8/8 [==============================] - 4s 196ms/step - loss: 1.2808 - accuracy: 0.6720 - val_loss: 0.9230 - val_accuracy: 0.4375
# Epoch 2/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.1452 - accuracy: 0.9680 - val_loss: 1.8175 - val_accuracy: 0.4375
# Epoch 3/60
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0189 - accuracy: 0.9920 - val_loss: 2.8980 - val_accuracy: 0.4375
# Epoch 4/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0191 - accuracy: 0.9920 - val_loss: 1.8025 - val_accuracy: 0.4375
# Epoch 5/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.1033 - val_accuracy: 0.4375
# Epoch 6/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0104 - accuracy: 0.9920 - val_loss: 3.1675 - val_accuracy: 0.4375
# Epoch 7/60
# 8/8 [==============================] - 1s 126ms/step - loss: 6.7338e-04 - accuracy: 1.0000 - val_loss: 3.9405 - val_accuracy: 0.4375
# Epoch 8/60
# 8/8 [==============================] - 1s 126ms/step - loss: 3.4646e-04 - accuracy: 1.0000 - val_loss: 3.7362 - val_accuracy: 0.4375
# Epoch 9/60
# 8/8 [==============================] - 1s 127ms/step - loss: 7.2160e-05 - accuracy: 1.0000 - val_loss: 3.4389 - val_accuracy: 0.4375
# Epoch 10/60
# 8/8 [==============================] - 1s 127ms/step - loss: 7.3125e-05 - accuracy: 1.0000 - val_loss: 3.2632 - val_accuracy: 0.4375
# Epoch 11/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.1308 - val_accuracy: 0.4375
# Epoch 12/60
# 8/8 [==============================] - 1s 126ms/step - loss: 4.8472e-05 - accuracy: 1.0000 - val_loss: 3.0075 - val_accuracy: 0.4375
# Epoch 13/60
# 8/8 [==============================] - 1s 126ms/step - loss: 1.9153e-04 - accuracy: 1.0000 - val_loss: 2.9854 - val_accuracy: 0.4375
# Epoch 14/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.3145 - val_accuracy: 0.4375
# Epoch 15/60
# 8/8 [==============================] - 1s 126ms/step - loss: 1.7876e-05 - accuracy: 1.0000 - val_loss: 4.3414 - val_accuracy: 0.4375
# Epoch 16/60
# 8/8 [==============================] - 1s 127ms/step - loss: 4.3998e-05 - accuracy: 1.0000 - val_loss: 4.8565 - val_accuracy: 0.4375
# Epoch 17/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 4.8666 - val_accuracy: 0.4375
# Epoch 18/60
# 8/8 [==============================] - 1s 127ms/step - loss: 4.3642e-05 - accuracy: 1.0000 - val_loss: 4.6508 - val_accuracy: 0.4375
# Epoch 19/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0105 - accuracy: 0.9920 - val_loss: 4.2491 - val_accuracy: 0.4375
# Epoch 20/60
# 8/8 [==============================] - 1s 126ms/step - loss: 1.4079e-05 - accuracy: 1.0000 - val_loss: 4.4385 - val_accuracy: 0.4375
# Epoch 21/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0362 - accuracy: 0.9840 - val_loss: 6.6138 - val_accuracy: 0.4375
# Epoch 22/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 6.1597 - val_accuracy: 0.4375
# Epoch 23/60
# 8/8 [==============================] - 1s 126ms/step - loss: 1.7240e-04 - accuracy: 1.0000 - val_loss: 4.9767 - val_accuracy: 0.4375
# Epoch 24/60
# 8/8 [==============================] - 1s 128ms/step - loss: 1.4369e-06 - accuracy: 1.0000 - val_loss: 4.5829 - val_accuracy: 0.4375
# Epoch 25/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 4.7655 - val_accuracy: 0.4375
# Epoch 26/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0159 - accuracy: 0.9920 - val_loss: 6.5650 - val_accuracy: 0.4375
# Epoch 27/60
# 8/8 [==============================] - 1s 127ms/step - loss: 8.9944e-04 - accuracy: 1.0000 - val_loss: 9.7622 - val_accuracy: 0.4375
# Epoch 28/60
# 8/8 [==============================] - 1s 126ms/step - loss: 6.5180e-04 - accuracy: 1.0000 - val_loss: 9.4309 - val_accuracy: 0.4375
# Epoch 29/60
# 8/8 [==============================] - 1s 126ms/step - loss: 1.2394e-04 - accuracy: 1.0000 - val_loss: 7.9723 - val_accuracy: 0.4375
# Epoch 30/60
# 8/8 [==============================] - 1s 126ms/step - loss: 2.2297e-05 - accuracy: 1.0000 - val_loss: 7.1498 - val_accuracy: 0.4375
# Epoch 31/60
# 8/8 [==============================] - 1s 126ms/step - loss: 5.5469e-04 - accuracy: 1.0000 - val_loss: 5.5209 - val_accuracy: 0.4375
# Epoch 32/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0100 - accuracy: 0.9920 - val_loss: 6.2481 - val_accuracy: 0.4375
# Epoch 33/60
# 8/8 [==============================] - 1s 126ms/step - loss: 1.0668e-05 - accuracy: 1.0000 - val_loss: 9.0330 - val_accuracy: 0.4375
# Epoch 34/60
# 8/8 [==============================] - 1s 126ms/step - loss: 6.2534e-04 - accuracy: 1.0000 - val_loss: 9.6885 - val_accuracy: 0.4375
# Epoch 35/60
# 8/8 [==============================] - 1s 126ms/step - loss: 5.9017e-05 - accuracy: 1.0000 - val_loss: 8.7991 - val_accuracy: 0.4375
# Epoch 36/60
# 8/8 [==============================] - 1s 126ms/step - loss: 3.0000e-04 - accuracy: 1.0000 - val_loss: 7.7421 - val_accuracy: 0.4375
# Epoch 37/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0061 - accuracy: 0.9920 - val_loss: 3.2839 - val_accuracy: 0.4375
# Epoch 38/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0462 - accuracy: 0.9840 - val_loss: 2.6560 - val_accuracy: 0.4375
# Epoch 39/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0153 - accuracy: 0.9920 - val_loss: 13.5438 - val_accuracy: 0.5625
# Epoch 40/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.3131 - accuracy: 0.9600 - val_loss: 11.8456 - val_accuracy: 0.4375
# Epoch 41/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.4638 - accuracy: 0.9680 - val_loss: 4.6015 - val_accuracy: 0.4375
# Epoch 42/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.2929 - accuracy: 0.9680 - val_loss: 2.2375 - val_accuracy: 0.5625
# Epoch 43/60
# 8/8 [==============================] - 1s 127ms/step - loss: 1.9725e-04 - accuracy: 1.0000 - val_loss: 0.8627 - val_accuracy: 0.5625
# Epoch 44/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0208 - accuracy: 0.9840 - val_loss: 1.7306 - val_accuracy: 0.4375
# Epoch 45/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0555 - accuracy: 0.9840 - val_loss: 3.7566 - val_accuracy: 0.4375
# Epoch 46/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0421 - accuracy: 0.9840 - val_loss: 6.0249 - val_accuracy: 0.4375
# Epoch 47/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.1273 - accuracy: 0.9760 - val_loss: 4.9209 - val_accuracy: 0.4375
# Epoch 48/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0107 - accuracy: 0.9920 - val_loss: 2.0184 - val_accuracy: 0.4375
# Epoch 49/60
# 8/8 [==============================] - 1s 126ms/step - loss: 5.6391e-05 - accuracy: 1.0000 - val_loss: 1.0888 - val_accuracy: 0.5625
# Epoch 50/60
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.5463 - val_accuracy: 0.5625
# Epoch 51/60
# 8/8 [==============================] - 1s 127ms/step - loss: 9.6938e-04 - accuracy: 1.0000 - val_loss: 1.8520 - val_accuracy: 0.5625
# Epoch 52/60
# 8/8 [==============================] - 1s 125ms/step - loss: 7.1737e-05 - accuracy: 1.0000 - val_loss: 1.8580 - val_accuracy: 0.5625
# Epoch 53/60
# 8/8 [==============================] - 1s 126ms/step - loss: 5.7272e-04 - accuracy: 1.0000 - val_loss: 1.5574 - val_accuracy: 0.5625
# Epoch 54/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.8865 - val_accuracy: 0.5312
# Epoch 55/60
# 8/8 [==============================] - 1s 126ms/step - loss: 1.0716e-05 - accuracy: 1.0000 - val_loss: 2.6487 - val_accuracy: 0.4375
# Epoch 56/60
# 8/8 [==============================] - 1s 126ms/step - loss: 2.1219e-06 - accuracy: 1.0000 - val_loss: 3.7807 - val_accuracy: 0.4375
# Epoch 57/60
# 8/8 [==============================] - 1s 127ms/step - loss: 3.1051e-04 - accuracy: 1.0000 - val_loss: 4.0812 - val_accuracy: 0.4375
# Epoch 58/60
# 8/8 [==============================] - 1s 126ms/step - loss: 1.1439e-04 - accuracy: 1.0000 - val_loss: 3.9563 - val_accuracy: 0.4375
# Epoch 59/60
# 8/8 [==============================] - 1s 126ms/step - loss: 1.7270e-05 - accuracy: 1.0000 - val_loss: 3.8649 - val_accuracy: 0.4375
# Epoch 60/60
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.4303 - val_accuracy: 0.4375
# c:\Users\andre\anaconda3\envs\TFenv\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in longlong_scalars
# Epoch 1/60
# 8/8 [==============================] - 5s 196ms/step - loss: 0.9373 - accuracy: 0.5840 - val_loss: 1.3945 - val_accuracy: 0.5625
# Epoch 2/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.4050 - accuracy: 0.7840 - val_loss: 0.9160 - val_accuracy: 0.5938
# Epoch 3/60
# 8/8 [==============================] - 1s 103ms/step - loss: 0.2067 - accuracy: 0.9280 - val_loss: 1.2651 - val_accuracy: 0.5938
# Epoch 4/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.1168 - accuracy: 0.9600 - val_loss: 0.6249 - val_accuracy: 0.6562
# Epoch 5/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0239 - accuracy: 0.9920 - val_loss: 0.3697 - val_accuracy: 0.8438
# Epoch 6/60
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.3287 - val_accuracy: 0.7812
# Epoch 7/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0278 - accuracy: 0.9760 - val_loss: 0.6357 - val_accuracy: 0.8125
# Epoch 8/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.9770 - val_accuracy: 0.7188
# Epoch 9/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0348 - accuracy: 0.9840 - val_loss: 0.3695 - val_accuracy: 0.8750
# Epoch 10/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9062
# Epoch 11/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1805 - val_accuracy: 0.9062
# Epoch 12/60
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0327 - accuracy: 0.9840 - val_loss: 0.2760 - val_accuracy: 0.9062
# Epoch 13/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.3235 - val_accuracy: 0.8125
# Epoch 14/60
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.8438
# Epoch 15/60
# 8/8 [==============================] - 1s 103ms/step - loss: 0.0320 - accuracy: 0.9920 - val_loss: 0.3454 - val_accuracy: 0.8438
# Epoch 16/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0149 - accuracy: 0.9920 - val_loss: 0.1770 - val_accuracy: 0.8750
# Epoch 17/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0308 - accuracy: 0.9920 - val_loss: 0.1250 - val_accuracy: 0.9375
# Epoch 18/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1060 - val_accuracy: 0.9688
# Epoch 19/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 0.9688
# Epoch 20/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9375
# Epoch 21/60
# 8/8 [==============================] - 1s 105ms/step - loss: 9.5800e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9688
# Epoch 22/60
# 8/8 [==============================] - 1s 104ms/step - loss: 6.1847e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9688
# Epoch 23/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9375
# Epoch 24/60
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9375
# Epoch 25/60
# 8/8 [==============================] - 1s 105ms/step - loss: 3.7583e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9688
# Epoch 26/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9688
# Epoch 27/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9375
# Epoch 28/60
# 8/8 [==============================] - 1s 104ms/step - loss: 3.9787e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9688
# Epoch 29/60
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9688
# Epoch 30/60
# 8/8 [==============================] - 1s 104ms/step - loss: 5.0524e-04 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9688
# Epoch 31/60
# 8/8 [==============================] - 1s 104ms/step - loss: 3.0715e-04 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9688
# Epoch 32/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9688
# Epoch 33/60
# 8/8 [==============================] - 1s 104ms/step - loss: 4.2393e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9688
# Epoch 34/60
# 8/8 [==============================] - 1s 104ms/step - loss: 8.7188e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9688
# Epoch 35/60
# 8/8 [==============================] - 1s 104ms/step - loss: 2.7179e-04 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9688
# Epoch 36/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9688
# Epoch 37/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9688
# Epoch 38/60
# 8/8 [==============================] - 1s 103ms/step - loss: 2.2190e-04 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 0.9688
# Epoch 39/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9688
# Epoch 40/60
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9688
# Epoch 41/60
# 8/8 [==============================] - 1s 105ms/step - loss: 4.7645e-05 - accuracy: 1.0000 - val_loss: 0.1785 - val_accuracy: 0.9688
# Epoch 42/60
# 8/8 [==============================] - 1s 105ms/step - loss: 2.7201e-04 - accuracy: 1.0000 - val_loss: 0.1746 - val_accuracy: 0.9688
# Epoch 43/60
# 8/8 [==============================] - 1s 105ms/step - loss: 5.6039e-05 - accuracy: 1.0000 - val_loss: 0.1747 - val_accuracy: 0.9688
# Epoch 44/60
# 8/8 [==============================] - 1s 106ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 45/60
# 8/8 [==============================] - 1s 104ms/step - loss: 4.8287e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 46/60
# 8/8 [==============================] - 1s 105ms/step - loss: 2.2458e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 47/60
# 8/8 [==============================] - 1s 103ms/step - loss: 6.8490e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 48/60
# 8/8 [==============================] - 1s 104ms/step - loss: 4.8484e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 49/60
# 8/8 [==============================] - 1s 104ms/step - loss: 5.9171e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 50/60
# 8/8 [==============================] - 1s 104ms/step - loss: 1.0083e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 51/60
# 8/8 [==============================] - 1s 105ms/step - loss: 1.5388e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 52/60
# 8/8 [==============================] - 1s 104ms/step - loss: 5.7456e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 53/60
# 8/8 [==============================] - 1s 104ms/step - loss: 2.5835e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 54/60
# 8/8 [==============================] - 1s 104ms/step - loss: 9.7293e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 55/60
# 8/8 [==============================] - 1s 106ms/step - loss: 1.5442e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 56/60
# 8/8 [==============================] - 1s 105ms/step - loss: 2.9182e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 57/60
# 8/8 [==============================] - 1s 104ms/step - loss: 1.4093e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 58/60
# 8/8 [==============================] - 1s 103ms/step - loss: 1.7140e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 59/60
# 8/8 [==============================] - 1s 103ms/step - loss: 4.0488e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 60/60
# 8/8 [==============================] - 1s 104ms/step - loss: 1.0722e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 1/60
# 8/8 [==============================] - 3s 150ms/step - loss: 1.1976 - accuracy: 0.5760 - val_loss: 0.3073 - val_accuracy: 0.9062
# Epoch 2/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.2031 - accuracy: 0.8960 - val_loss: 0.3397 - val_accuracy: 0.8438
# Epoch 3/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0440 - accuracy: 0.9840 - val_loss: 0.3333 - val_accuracy: 0.8438
# Epoch 4/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0256 - accuracy: 0.9840 - val_loss: 0.5811 - val_accuracy: 0.7812
# Epoch 5/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.4775 - val_accuracy: 0.7812
# Epoch 6/60
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3376 - val_accuracy: 0.8438
# Epoch 7/60
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.8438
# Epoch 8/60
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2892 - val_accuracy: 0.8438
# Epoch 9/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.8750
# Epoch 10/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2765 - val_accuracy: 0.9062
# Epoch 11/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.3005 - val_accuracy: 0.8125
# Epoch 12/60
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.4210 - val_accuracy: 0.6875
# Epoch 13/60
# 8/8 [==============================] - 1s 87ms/step - loss: 3.4485e-04 - accuracy: 1.0000 - val_loss: 0.4478 - val_accuracy: 0.6562
# Epoch 14/60
# 8/8 [==============================] - 1s 84ms/step - loss: 7.2246e-04 - accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 0.8125
# Epoch 15/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4857 - val_accuracy: 0.6250
# Epoch 16/60
# 8/8 [==============================] - 1s 85ms/step - loss: 3.9086e-04 - accuracy: 1.0000 - val_loss: 0.6235 - val_accuracy: 0.6250
# Epoch 17/60
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0218 - accuracy: 0.9920 - val_loss: 0.2094 - val_accuracy: 0.8750
# Epoch 18/60
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0120 - accuracy: 0.9920 - val_loss: 0.2295 - val_accuracy: 0.8438
# Epoch 19/60
# 8/8 [==============================] - 1s 86ms/step - loss: 5.7573e-04 - accuracy: 1.0000 - val_loss: 0.3312 - val_accuracy: 0.8438
# Epoch 20/60
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3271 - val_accuracy: 0.8750
# Epoch 21/60
# 8/8 [==============================] - 1s 86ms/step - loss: 1.6473e-04 - accuracy: 1.0000 - val_loss: 0.3019 - val_accuracy: 0.8438
# Epoch 22/60
# 8/8 [==============================] - 1s 84ms/step - loss: 4.0667e-04 - accuracy: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.8438
# Epoch 23/60
# 8/8 [==============================] - 1s 86ms/step - loss: 2.0095e-04 - accuracy: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.8438
# Epoch 24/60
# 8/8 [==============================] - 1s 88ms/step - loss: 2.9265e-04 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.8438
# Epoch 25/60
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.4207 - val_accuracy: 0.8750
# Epoch 26/60
# 8/8 [==============================] - 1s 85ms/step - loss: 4.8712e-04 - accuracy: 1.0000 - val_loss: 0.5508 - val_accuracy: 0.8125
# Epoch 27/60
# 8/8 [==============================] - 1s 87ms/step - loss: 8.8296e-04 - accuracy: 1.0000 - val_loss: 0.4812 - val_accuracy: 0.8438
# Epoch 28/60
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0060 - accuracy: 0.9920 - val_loss: 0.4025 - val_accuracy: 0.9062
# Epoch 29/60
# 8/8 [==============================] - 1s 85ms/step - loss: 1.4173e-04 - accuracy: 1.0000 - val_loss: 0.3296 - val_accuracy: 0.8750
# Epoch 30/60
# 8/8 [==============================] - 1s 85ms/step - loss: 5.0175e-05 - accuracy: 1.0000 - val_loss: 0.3451 - val_accuracy: 0.8438
# Epoch 31/60
# 8/8 [==============================] - 1s 84ms/step - loss: 3.9034e-04 - accuracy: 1.0000 - val_loss: 0.3552 - val_accuracy: 0.8438
# Epoch 32/60
# 8/8 [==============================] - 1s 86ms/step - loss: 6.0437e-04 - accuracy: 1.0000 - val_loss: 0.3750 - val_accuracy: 0.8438
# Epoch 33/60
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.8750
# Epoch 34/60
# 8/8 [==============================] - 1s 88ms/step - loss: 6.6921e-05 - accuracy: 1.0000 - val_loss: 0.7148 - val_accuracy: 0.8438
# Epoch 35/60
# 8/8 [==============================] - 1s 85ms/step - loss: 2.9471e-04 - accuracy: 1.0000 - val_loss: 0.7463 - val_accuracy: 0.8438
# Epoch 36/60
# 8/8 [==============================] - 1s 86ms/step - loss: 2.2451e-04 - accuracy: 1.0000 - val_loss: 0.6455 - val_accuracy: 0.8750
# Epoch 37/60
# 8/8 [==============================] - 1s 86ms/step - loss: 2.6545e-04 - accuracy: 1.0000 - val_loss: 0.6335 - val_accuracy: 0.8750
# Epoch 38/60
# 8/8 [==============================] - 1s 85ms/step - loss: 1.4905e-04 - accuracy: 1.0000 - val_loss: 0.6085 - val_accuracy: 0.8750
# Epoch 39/60
# 8/8 [==============================] - 1s 87ms/step - loss: 1.4432e-04 - accuracy: 1.0000 - val_loss: 0.6021 - val_accuracy: 0.8750
# Epoch 40/60
# 8/8 [==============================] - 1s 86ms/step - loss: 4.7732e-05 - accuracy: 1.0000 - val_loss: 0.6128 - val_accuracy: 0.8750
# Epoch 41/60
# 8/8 [==============================] - 1s 86ms/step - loss: 1.4601e-05 - accuracy: 1.0000 - val_loss: 0.6177 - val_accuracy: 0.8750
# Epoch 42/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.3959 - val_accuracy: 0.9062
# Epoch 43/60
# 8/8 [==============================] - 1s 85ms/step - loss: 1.3365e-04 - accuracy: 1.0000 - val_loss: 0.3881 - val_accuracy: 0.9062
# Epoch 44/60
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4199 - val_accuracy: 0.9062
# Epoch 45/60
# 8/8 [==============================] - 1s 84ms/step - loss: 2.1704e-04 - accuracy: 1.0000 - val_loss: 0.4534 - val_accuracy: 0.8750
# Epoch 46/60
# 8/8 [==============================] - 1s 86ms/step - loss: 1.5644e-04 - accuracy: 1.0000 - val_loss: 0.4645 - val_accuracy: 0.8750
# Epoch 47/60
# 8/8 [==============================] - 1s 86ms/step - loss: 3.8801e-05 - accuracy: 1.0000 - val_loss: 0.4752 - val_accuracy: 0.8750
# Epoch 48/60
# 8/8 [==============================] - 1s 85ms/step - loss: 2.4030e-04 - accuracy: 1.0000 - val_loss: 0.4331 - val_accuracy: 0.8750
# Epoch 49/60
# 8/8 [==============================] - 1s 85ms/step - loss: 1.5936e-04 - accuracy: 1.0000 - val_loss: 0.4131 - val_accuracy: 0.8750
# Epoch 50/60
# 8/8 [==============================] - 1s 86ms/step - loss: 8.3546e-06 - accuracy: 1.0000 - val_loss: 0.4144 - val_accuracy: 0.8750
# Epoch 51/60
# 8/8 [==============================] - 1s 84ms/step - loss: 7.3420e-04 - accuracy: 1.0000 - val_loss: 0.4641 - val_accuracy: 0.8750
# Epoch 52/60
# 8/8 [==============================] - 1s 84ms/step - loss: 2.0005e-05 - accuracy: 1.0000 - val_loss: 0.5286 - val_accuracy: 0.8750
# Epoch 53/60
# 8/8 [==============================] - 1s 86ms/step - loss: 5.7486e-06 - accuracy: 1.0000 - val_loss: 0.5591 - val_accuracy: 0.8750
# Epoch 54/60
# 8/8 [==============================] - 1s 85ms/step - loss: 9.6019e-04 - accuracy: 1.0000 - val_loss: 0.5789 - val_accuracy: 0.8750
# Epoch 55/60
# 8/8 [==============================] - 1s 87ms/step - loss: 9.5951e-06 - accuracy: 1.0000 - val_loss: 0.6091 - val_accuracy: 0.8750
# Epoch 56/60
# 8/8 [==============================] - 1s 86ms/step - loss: 1.8249e-04 - accuracy: 1.0000 - val_loss: 0.5782 - val_accuracy: 0.8750
# Epoch 57/60
# 8/8 [==============================] - 1s 84ms/step - loss: 2.7466e-04 - accuracy: 1.0000 - val_loss: 0.5372 - val_accuracy: 0.8750
# Epoch 58/60
# 8/8 [==============================] - 1s 86ms/step - loss: 3.8896e-05 - accuracy: 1.0000 - val_loss: 0.4892 - val_accuracy: 0.8750
# Epoch 59/60
# 8/8 [==============================] - 1s 83ms/step - loss: 3.5707e-05 - accuracy: 1.0000 - val_loss: 0.4876 - val_accuracy: 0.8750
# Epoch 60/60
# 8/8 [==============================] - 1s 86ms/step - loss: 2.0678e-06 - accuracy: 1.0000 - val_loss: 0.4768 - val_accuracy: 0.8750
# Epoch 1/60
# 8/8 [==============================] - 6s 238ms/step - loss: 0.7662 - accuracy: 0.5920 - val_loss: 0.7016 - val_accuracy: 0.5625
# Epoch 2/60
# 8/8 [==============================] - 1s 134ms/step - loss: 0.1713 - accuracy: 0.9200 - val_loss: 0.9859 - val_accuracy: 0.4375
# Epoch 3/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0577 - accuracy: 0.9760 - val_loss: 1.4026 - val_accuracy: 0.4375
# Epoch 4/60
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0190 - accuracy: 0.9920 - val_loss: 1.4953 - val_accuracy: 0.4375
# Epoch 5/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.4974 - val_accuracy: 0.4375
# Epoch 6/60
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0156 - accuracy: 0.9920 - val_loss: 1.4964 - val_accuracy: 0.4375
# Epoch 7/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.4993 - val_accuracy: 0.4375
# Epoch 8/60
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.5283 - val_accuracy: 0.4375
# Epoch 9/60
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.5617 - val_accuracy: 0.4375
# Epoch 10/60
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.6175 - val_accuracy: 0.4375
# Epoch 11/60
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0083 - accuracy: 0.9920 - val_loss: 1.6819 - val_accuracy: 0.4375
# Epoch 12/60
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0141 - accuracy: 0.9920 - val_loss: 1.9124 - val_accuracy: 0.4375
# Epoch 13/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.4603 - val_accuracy: 0.4375
# Epoch 14/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.0562 - val_accuracy: 0.4375
# Epoch 15/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.9484 - val_accuracy: 0.4375
# Epoch 16/60
# 8/8 [==============================] - 1s 133ms/step - loss: 7.7942e-04 - accuracy: 1.0000 - val_loss: 1.7975 - val_accuracy: 0.4375
# Epoch 17/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4656 - val_accuracy: 0.4375
# Epoch 18/60
# 8/8 [==============================] - 1s 134ms/step - loss: 4.2991e-04 - accuracy: 1.0000 - val_loss: 1.1991 - val_accuracy: 0.4375
# Epoch 19/60
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0514 - val_accuracy: 0.4375
# Epoch 20/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.9840 - val_accuracy: 0.4375
# Epoch 21/60
# 8/8 [==============================] - 1s 133ms/step - loss: 4.0675e-04 - accuracy: 1.0000 - val_loss: 0.9727 - val_accuracy: 0.4375
# Epoch 22/60
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.9467 - val_accuracy: 0.4375
# Epoch 23/60
# 8/8 [==============================] - 1s 130ms/step - loss: 2.4269e-04 - accuracy: 1.0000 - val_loss: 0.9411 - val_accuracy: 0.4375
# Epoch 24/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.9425 - val_accuracy: 0.4375
# Epoch 25/60
# 8/8 [==============================] - 1s 132ms/step - loss: 5.1732e-04 - accuracy: 1.0000 - val_loss: 0.9587 - val_accuracy: 0.4375
# Epoch 26/60
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.9596 - val_accuracy: 0.4375
# Epoch 27/60
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.9254 - val_accuracy: 0.4375
# Epoch 28/60
# 8/8 [==============================] - 1s 133ms/step - loss: 5.1332e-04 - accuracy: 1.0000 - val_loss: 0.9239 - val_accuracy: 0.4375
# Epoch 29/60
# 8/8 [==============================] - 1s 132ms/step - loss: 6.1363e-04 - accuracy: 1.0000 - val_loss: 0.9099 - val_accuracy: 0.4375
# Epoch 30/60
# 8/8 [==============================] - 1s 133ms/step - loss: 4.0906e-04 - accuracy: 1.0000 - val_loss: 0.8619 - val_accuracy: 0.4375
# Epoch 31/60
# 8/8 [==============================] - 1s 132ms/step - loss: 1.7214e-04 - accuracy: 1.0000 - val_loss: 0.8413 - val_accuracy: 0.4375
# Epoch 32/60
# 8/8 [==============================] - 1s 132ms/step - loss: 4.5675e-04 - accuracy: 1.0000 - val_loss: 0.8452 - val_accuracy: 0.4375
# Epoch 33/60
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8651 - val_accuracy: 0.4375
# Epoch 34/60
# 8/8 [==============================] - 1s 130ms/step - loss: 4.3922e-04 - accuracy: 1.0000 - val_loss: 0.9172 - val_accuracy: 0.4375
# Epoch 35/60
# 8/8 [==============================] - 1s 133ms/step - loss: 9.0908e-04 - accuracy: 1.0000 - val_loss: 0.9797 - val_accuracy: 0.4375
# Epoch 36/60
# 8/8 [==============================] - 1s 133ms/step - loss: 8.1279e-04 - accuracy: 1.0000 - val_loss: 1.0370 - val_accuracy: 0.4375
# Epoch 37/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0922 - val_accuracy: 0.4375
# Epoch 38/60
# 8/8 [==============================] - 1s 133ms/step - loss: 2.7741e-04 - accuracy: 1.0000 - val_loss: 1.1111 - val_accuracy: 0.4375
# Epoch 39/60
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.1583 - val_accuracy: 0.4375
# Epoch 40/60
# 8/8 [==============================] - 1s 132ms/step - loss: 4.2207e-04 - accuracy: 1.0000 - val_loss: 1.1515 - val_accuracy: 0.4375
# Epoch 41/60
# 8/8 [==============================] - 1s 131ms/step - loss: 1.4985e-04 - accuracy: 1.0000 - val_loss: 1.2004 - val_accuracy: 0.4375
# Epoch 42/60
# 8/8 [==============================] - 1s 131ms/step - loss: 7.7688e-04 - accuracy: 1.0000 - val_loss: 1.2966 - val_accuracy: 0.4375
# Epoch 43/60
# 8/8 [==============================] - 1s 135ms/step - loss: 1.8789e-04 - accuracy: 1.0000 - val_loss: 1.2044 - val_accuracy: 0.4375
# Epoch 44/60
# 8/8 [==============================] - 1s 131ms/step - loss: 4.6277e-04 - accuracy: 1.0000 - val_loss: 1.1101 - val_accuracy: 0.4688
# Epoch 45/60
# 8/8 [==============================] - 1s 132ms/step - loss: 7.2177e-04 - accuracy: 1.0000 - val_loss: 1.1512 - val_accuracy: 0.4375
# Epoch 46/60
# 8/8 [==============================] - 1s 130ms/step - loss: 1.4335e-04 - accuracy: 1.0000 - val_loss: 1.1049 - val_accuracy: 0.4062
# Epoch 47/60
# 8/8 [==============================] - 1s 132ms/step - loss: 1.2905e-04 - accuracy: 1.0000 - val_loss: 0.9919 - val_accuracy: 0.3750
# Epoch 48/60
# 8/8 [==============================] - 1s 131ms/step - loss: 5.2110e-04 - accuracy: 1.0000 - val_loss: 0.9610 - val_accuracy: 0.4062
# Epoch 49/60
# 8/8 [==============================] - 1s 132ms/step - loss: 1.4942e-04 - accuracy: 1.0000 - val_loss: 0.9675 - val_accuracy: 0.4688
# Epoch 50/60
# 8/8 [==============================] - 1s 132ms/step - loss: 1.3087e-04 - accuracy: 1.0000 - val_loss: 0.9894 - val_accuracy: 0.4062
# Epoch 51/60
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.9836 - val_accuracy: 0.4688
# Epoch 52/60
# 8/8 [==============================] - 1s 133ms/step - loss: 3.4527e-05 - accuracy: 1.0000 - val_loss: 1.0003 - val_accuracy: 0.4375
# Epoch 53/60
# 8/8 [==============================] - 1s 136ms/step - loss: 2.8811e-04 - accuracy: 1.0000 - val_loss: 0.9763 - val_accuracy: 0.4375
# Epoch 54/60
# 8/8 [==============================] - 1s 132ms/step - loss: 3.1407e-04 - accuracy: 1.0000 - val_loss: 0.9459 - val_accuracy: 0.4375
# Epoch 55/60
# 8/8 [==============================] - 1s 134ms/step - loss: 2.4031e-04 - accuracy: 1.0000 - val_loss: 0.9434 - val_accuracy: 0.4688
# Epoch 56/60
# 8/8 [==============================] - 1s 131ms/step - loss: 3.7307e-04 - accuracy: 1.0000 - val_loss: 0.9508 - val_accuracy: 0.4375
# Epoch 57/60
# 8/8 [==============================] - 1s 132ms/step - loss: 4.9553e-04 - accuracy: 1.0000 - val_loss: 0.9319 - val_accuracy: 0.4375
# Epoch 58/60
# 8/8 [==============================] - 1s 133ms/step - loss: 9.6687e-05 - accuracy: 1.0000 - val_loss: 0.9160 - val_accuracy: 0.4375
# Epoch 59/60
# 8/8 [==============================] - 1s 132ms/step - loss: 1.5936e-04 - accuracy: 1.0000 - val_loss: 0.9095 - val_accuracy: 0.4375
# Epoch 60/60
# 8/8 [==============================] - 1s 134ms/step - loss: 5.5354e-04 - accuracy: 1.0000 - val_loss: 0.8708 - val_accuracy: 0.4375
#            Modelo  Acuracia  Sensibilidade  Especificidade   F-Score   AUC-ROC
# 0           VGG16     0.900       0.947368        0.857143  0.900000  0.902256
# 1        ResNet50     0.525       0.000000        1.000000  0.000000  0.500000
# 2     InceptionV3     0.925       0.947368        0.904762  0.923077  0.926065
# 3     MobileNetV2     0.950       0.894737        1.000000  0.944444  0.947368
# 4  EfficientNetB0     0.500       0.000000        0.952381  0.000000  0.476190
