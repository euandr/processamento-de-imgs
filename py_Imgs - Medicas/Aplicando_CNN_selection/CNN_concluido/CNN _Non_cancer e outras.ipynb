# %%
import os
import gc
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, cohen_kappa_score
import tensorflow as tf
# 001
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, ResNet50, DenseNet121, InceptionV3, EfficientNetB0, Xception, MobileNetV2
from tensorflow.keras import models, layers, optimizers, callbacks
from tensorflow.keras import backend as K

# 002
# from keras._tf_keras.keras.preprocessing.image import  ImageDataGenerator
# from keras._tf_keras.keras.applications import VGG16, ResNet50, DenseNet121, InceptionV3, EfficientNetB0, Xception, MobileNetV2
# from keras._tf_keras.keras import models, layers, optimizers, callbacks
# from keras._tf_keras.keras import backend as K


print("Todas as bibliotecas foram importadas com sucesso!")
# Out:
# Todas as bibliotecas foram importadas com sucesso!

# %%
# Criando função para calcular as métricas

def get_metrics(y_true, y_pred):
    vn, fp, fn, vp = confusion_matrix(y_true, y_pred).ravel()
    accuracy = (vp + vn) / (vp + fp + fn + vn)  
    recall = vp / (vp + fn)
    specificity = vn / (vn + fp)
    precision = vp / (vp + fp)
    f1 = f1_score(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)
    auc_roc = roc_auc_score(y_true, y_pred)

    return {
        'accuracy': accuracy,
        'specificity': specificity,
        'recall': recall,
        'precision': precision,
        'f1-score': f1,
        'kappa': kappa,
        'auc-roc': auc_roc
    }

# %%
# Criando função para seleção de esquema de cor 
def convert_color_scale(image, scale):
    if scale == 'hsv':
        return cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    elif scale == 'rgb':
        return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    elif scale == 'grayscale':
        # Converter para escala de cinza e replicar para 3 canais
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        return cv2.merge([gray, gray, gray])
    elif scale == 'lab':
        return cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    elif scale == 'luv':
        return cv2.cvtColor(image, cv2.COLOR_BGR2LUV)
    elif scale == 'xyz':
        return cv2.cvtColor(image, cv2.COLOR_BGR2XYZ)
    else:
        raise ValueError("Escala de cor não suportada.")

# %%
# Carregamento e pré-processamento de imagens com escolha de escala de cor

def load_images(folder, color_scale, img_extensions):
    images = []
    for filename in os.listdir(folder):
        if any(filename.lower().endswith(ext) for ext in img_extensions):
            img_path = os.path.join(folder, filename)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, (224, 224))  # Ajuste o tamanho conforme necessário
                img = convert_color_scale(img, color_scale)  # Converta para a escala de cor desejada
                # Se a imagem estiver em escala de cinza, expanda as dimensões
                if color_scale == 'grayscale':
                    img = np.expand_dims(img, axis=-1)  # Adiciona uma dimensão de canal
                images.append(img)

    return np.array(images)

# %%
# Defina as pastas de dados
data_dir = r"C:\Users\andre\Pictures\OvarianCancer"

normal_dir = os.path.join(data_dir, 'Non_Cancerous')
endometri = os.path.join(data_dir, 'Endometri')
Clear_Cell = os.path.join(data_dir, 'Clear_Cell')
Mucinous = os.path.join(data_dir, 'Mucinous')
Serous = os.path.join(data_dir, 'Serous')

img_extensions = ['.jpg', '.jpeg', '.png']

if os.listdir(normal_dir):print("pasta acesada, na pasta normal ha itens")
if os.listdir(endometri):print("pasta acessada, na pasta endometri ha itens")
if os.listdir(Clear_Cell):print("pasta acessada, na pasta Clear_Cell ha itens")
if os.listdir(Mucinous):print("pasta acessada, na pasta Mucinous ha itens")
if os.listdir(Serous):print("pasta acessada, na pasta Serous ha itens")
# Out:
# pasta acesada, na pasta normal ha itens
# pasta acessada, na pasta endometri ha itens
# pasta acessada, na pasta Clear_Cell ha itens
# pasta acessada, na pasta Mucinous ha itens
# pasta acessada, na pasta Serous ha itens

# %%
# Criar um DataFrame para armazenar os resultados
columns = ['Modelo', 'Acuracia', 'Sensibilidade', 'Especificidade', 'F-Score', 'AUC-ROC']
df_metrics = pd.DataFrame(columns=columns)

# Definir o caminho para salvar o melhor modelo
model_checkpoint_path = r"C:\Users\andre\Documents\atividades\estudos_opencv\introd_processamento de imagens\Aplicando_CNN_selection\\CNN-best_model.h5"

# %%
# Iterar sobre os modelos
def model_execution(model_name,pasta_com_nonCancer):

    # Carregamento de imagens e conversão para XYZ
    normal_images = load_images(normal_dir, 'xyz',img_extensions)
    cancer_images = load_images(pasta_com_nonCancer, 'xyz',img_extensions)

    # Rótulos para imagens (0 para normal, 1 para câncer)
    normal_labels = np.zeros(normal_images.shape[0])
    cancer_labels = np.ones(cancer_images.shape[0])

    # Concatenar imagens e rótulos
    all_images = np.concatenate([normal_images, cancer_images], axis=0)
    all_labels = np.concatenate([normal_labels, cancer_labels], axis=0)

    # Dividir o conjunto de dados em treino e teste (80/20)
    X_train, X_test, y_train, y_test = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)

    # Escolha entre 5 tipos de conversão de escala de cor aqui (por exemplo, normalização)
    X_train = X_train / 255.0
    X_test = X_test / 255.0

    # Escolher o modelo de CNN
    if model_name == 'VGG16':
        base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'ResNet50':
        base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'MobileNetV2':
        base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'InceptionV3':
        base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'EfficientNetB0':
        base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'Xception':
        base_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    elif model_name == 'VisionTransformer':
        base_model = VitB16(image_size=(224, 224), weights='imagenet', include_top=False)
    else:
        raise ValueError("Modelo de CNN não suportado.")

    # Construir o modelo
    model = models.Sequential()
    model.add(base_model)
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))

    # Compilar o modelo
    model.compile(optimizer=optimizers.Adam(learning_rate=1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Configurar o retorno de chamada ModelCheckpoint
    checkpoint = callbacks.ModelCheckpoint(model_checkpoint_path,
                                           monitor='val_accuracy',  # Métrica a ser monitorad
                                           mode='max',               # Salvar o modelo com a maior precisão
                                           verbose=1)

    # Treinar o modelo
    model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.2)  #  16 <<====

    # Avaliar o modelo
    y_pred = model.predict(X_test)
    y_pred_binary = (y_pred > 0.5).astype(int)

    # Calcular métricas
    metrics = get_metrics(y_test, y_pred_binary)

    # Adicionar as métricas ao DataFrame
    metrics['Modelo'] = model_name
    
    # Excluir o modelo atual para liberar memória da GPU   
    del all_images, normal_images, cancer_images, X_train, X_test, y_train, y_test, y_pred, y_pred_binary
    del all_labels, normal_labels, cancer_labels
    tf.keras.backend.clear_session()
    del model, base_model
    gc.collect()
    
    return metrics

# %%
chosen_model = 'VGG16'
#       ENDOMETRI
metrics = model_execution(chosen_model,endometri)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics1 = pd.concat([df_metrics, temp_df], ignore_index=True)
#       Clear_Cell  
metrics = model_execution(chosen_model,Clear_Cell) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics2 = pd.concat([df_metrics, temp_df], ignore_index=True) # <==
#       Mucinous
metrics = model_execution(chosen_model,Mucinous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics3 = pd.concat([df_metrics, temp_df], ignore_index=True) # <==
#       Serous
metrics = model_execution(chosen_model,Serous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics4 = pd.concat([df_metrics, temp_df], ignore_index=True) # <==



chosen_model = 'ResNet50'
#       ENDOMETRI
metrics = model_execution(chosen_model,endometri)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics1 = pd.concat([df_metrics1, temp_df], ignore_index=True)
#       Clear_Cell  
metrics = model_execution(chosen_model,Clear_Cell) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics2 = pd.concat([df_metrics2, temp_df], ignore_index=True) # <==
#       Mucinous
metrics = model_execution(chosen_model,Mucinous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics3 = pd.concat([df_metrics3, temp_df], ignore_index=True) # <==
#       Serous
metrics = model_execution(chosen_model,Serous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics4 = pd.concat([df_metrics4, temp_df], ignore_index=True) # <==



chosen_model = 'InceptionV3'
#       ENDOMETRI
metrics = model_execution(chosen_model,endometri)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics1 = pd.concat([df_metrics1, temp_df], ignore_index=True)
#       Clear_Cell  
metrics = model_execution(chosen_model,Clear_Cell) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics2 = pd.concat([df_metrics2, temp_df], ignore_index=True) # <==
#       Mucinous
metrics = model_execution(chosen_model,Mucinous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics3 = pd.concat([df_metrics3, temp_df], ignore_index=True) # <==
#       Serous
metrics = model_execution(chosen_model,Serous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics4 = pd.concat([df_metrics4, temp_df], ignore_index=True) # <==



chosen_model = 'MobileNetV2'
#       ENDOMETRI
metrics = model_execution(chosen_model,endometri)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics1 = pd.concat([df_metrics1, temp_df], ignore_index=True)
#       Clear_Cell  
metrics = model_execution(chosen_model,Clear_Cell) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics2 = pd.concat([df_metrics2, temp_df], ignore_index=True) # <==
#       Mucinous
metrics = model_execution(chosen_model,Mucinous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics3 = pd.concat([df_metrics3, temp_df], ignore_index=True) # <==
#       Serous
metrics = model_execution(chosen_model,Serous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics4 = pd.concat([df_metrics4, temp_df], ignore_index=True) # <==



chosen_model = 'EfficientNetB0'
#       ENDOMETRI
metrics = model_execution(chosen_model,endometri)
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics1 = pd.concat([df_metrics1, temp_df], ignore_index=True)
#       Clear_Cell  
metrics = model_execution(chosen_model,Clear_Cell) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics2 = pd.concat([df_metrics2, temp_df], ignore_index=True) # <==
#       Mucinous
metrics = model_execution(chosen_model,Mucinous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics3 = pd.concat([df_metrics3, temp_df], ignore_index=True) # <==
#       Serous
metrics = model_execution(chosen_model,Serous) # <==
temp_df = pd.DataFrame([[chosen_model, metrics['accuracy'], metrics['recall'], metrics['specificity'], metrics['f1-score'], metrics['auc-roc']]], columns=columns)  
df_metrics4 = pd.concat([df_metrics4, temp_df], ignore_index=True) # <==



print("\033[32m-------    ENDOMETRI e NON_CONCEROUS   ------\033[m ")
display(df_metrics1)

print("\033[32m-------    Clear_Cell e NON_CONCEROUS   ------\033[m ")
display(df_metrics2)

print("\033[32m-------    Mucinous e NON_CONCEROUS   ------\033[m ")
display(df_metrics3)

print("\033[32m-------    Serous e NON_CONCEROUS   ------\033[m ")
display(df_metrics4)


# # Adicionar identificadores
# df_metrics1['Identificador'] = 'ENDOMETRI e NON_CONCEROUS'
# df_metrics2['Identificador'] = 'Clear_Cell e NON_CONCEROUS'
# df_metrics3['Identificador'] = 'Mucinous e NON_CONCEROUS'
# df_metrics4['Identificador'] = 'Serous e NON_CONCEROUS'

# # Adicionar linhas vazias entre os DataFrames
# empty_row = pd.DataFrame([[''] * len(df_metrics1.columns)], columns=df_metrics1.columns)

# # Concatenar DataFrames com linhas vazias entre eles
# combined_df = pd.concat([
#     df_metrics1, empty_row, 
#     df_metrics2, empty_row, 
#     df_metrics3, empty_row, 
#     df_metrics4
# ], ignore_index=True)

# # Salvar no Excel
# combined_df.to_excel('CNN-combined_metrics_HSV.xlsx', index=False, sheet_name='Metrics')
# Out:
# Epoch 1/50
# 8/8 [==============================] - 2s 166ms/step - loss: 0.7689 - accuracy: 0.4640 - val_loss: 0.6632 - val_accuracy: 0.5938
# Epoch 2/50
# 8/8 [==============================] - 1s 146ms/step - loss: 0.6809 - accuracy: 0.5920 - val_loss: 0.6661 - val_accuracy: 0.4688
# Epoch 3/50
# 8/8 [==============================] - 1s 145ms/step - loss: 0.6899 - accuracy: 0.5840 - val_loss: 0.6346 - val_accuracy: 0.5938
# Epoch 4/50
# 8/8 [==============================] - 1s 144ms/step - loss: 0.6798 - accuracy: 0.5920 - val_loss: 0.5947 - val_accuracy: 0.8750
# Epoch 5/50
# 8/8 [==============================] - 1s 143ms/step - loss: 0.5217 - accuracy: 0.7840 - val_loss: 0.3341 - val_accuracy: 0.9062
# Epoch 6/50
# 8/8 [==============================] - 1s 145ms/step - loss: 0.2541 - accuracy: 0.9200 - val_loss: 0.2720 - val_accuracy: 0.9062
# Epoch 7/50
# 8/8 [==============================] - 1s 144ms/step - loss: 0.2479 - accuracy: 0.9120 - val_loss: 0.1520 - val_accuracy: 0.9375
# Epoch 8/50
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1753 - accuracy: 0.9280 - val_loss: 0.2714 - val_accuracy: 0.9062
# Epoch 9/50
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1594 - accuracy: 0.9760 - val_loss: 1.0232 - val_accuracy: 0.8438
# Epoch 10/50
# 8/8 [==============================] - 1s 144ms/step - loss: 0.3583 - accuracy: 0.8720 - val_loss: 0.5152 - val_accuracy: 0.8750
# Epoch 11/50
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1591 - accuracy: 0.9440 - val_loss: 0.1956 - val_accuracy: 0.9375
# Epoch 12/50
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0615 - accuracy: 0.9840 - val_loss: 0.4359 - val_accuracy: 0.9375
# Epoch 13/50
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0232 - accuracy: 0.9840 - val_loss: 0.8082 - val_accuracy: 0.9375
# Epoch 14/50
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1921 - accuracy: 0.9600 - val_loss: 0.6927 - val_accuracy: 0.7500
# Epoch 15/50
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1291 - accuracy: 0.9680 - val_loss: 0.5429 - val_accuracy: 0.9375
# Epoch 16/50
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0989 - accuracy: 0.9520 - val_loss: 0.4874 - val_accuracy: 0.8438
# Epoch 17/50
# 8/8 [==============================] - 1s 143ms/step - loss: 0.0555 - accuracy: 0.9920 - val_loss: 0.3086 - val_accuracy: 0.8750
# Epoch 18/50
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.4680 - val_accuracy: 0.9062
# Epoch 19/50
# 8/8 [==============================] - 1s 143ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.7604 - val_accuracy: 0.8438
# Epoch 20/50
# 8/8 [==============================] - 1s 144ms/step - loss: 5.4900e-04 - accuracy: 1.0000 - val_loss: 0.7960 - val_accuracy: 0.9062
# Epoch 21/50
# 8/8 [==============================] - 1s 144ms/step - loss: 8.2372e-04 - accuracy: 1.0000 - val_loss: 0.8851 - val_accuracy: 0.9062
# Epoch 22/50
# 8/8 [==============================] - 1s 143ms/step - loss: 6.7947e-04 - accuracy: 1.0000 - val_loss: 0.9734 - val_accuracy: 0.9062
# Epoch 23/50
# 8/8 [==============================] - 1s 145ms/step - loss: 2.2342e-04 - accuracy: 1.0000 - val_loss: 1.0402 - val_accuracy: 0.9062
# Epoch 24/50
# 8/8 [==============================] - 1s 144ms/step - loss: 8.1727e-04 - accuracy: 1.0000 - val_loss: 1.0927 - val_accuracy: 0.9062
# Epoch 25/50
# 8/8 [==============================] - 1s 144ms/step - loss: 5.4260e-05 - accuracy: 1.0000 - val_loss: 1.0924 - val_accuracy: 0.9062
# Epoch 26/50
# 8/8 [==============================] - 1s 144ms/step - loss: 3.4567e-04 - accuracy: 1.0000 - val_loss: 1.0950 - val_accuracy: 0.9062
# Epoch 27/50
# 8/8 [==============================] - 1s 143ms/step - loss: 4.2973e-04 - accuracy: 1.0000 - val_loss: 1.0615 - val_accuracy: 0.9062
# Epoch 28/50
# 8/8 [==============================] - 1s 144ms/step - loss: 5.1954e-05 - accuracy: 1.0000 - val_loss: 1.0562 - val_accuracy: 0.9062
# Epoch 29/50
# 8/8 [==============================] - 1s 144ms/step - loss: 5.8623e-04 - accuracy: 1.0000 - val_loss: 1.1262 - val_accuracy: 0.9062
# Epoch 30/50
# 8/8 [==============================] - 1s 143ms/step - loss: 3.0396e-05 - accuracy: 1.0000 - val_loss: 1.2800 - val_accuracy: 0.8438
# Epoch 31/50
# 8/8 [==============================] - 1s 144ms/step - loss: 1.9557e-05 - accuracy: 1.0000 - val_loss: 1.3683 - val_accuracy: 0.8438
# Epoch 32/50
# 8/8 [==============================] - 1s 144ms/step - loss: 4.4815e-06 - accuracy: 1.0000 - val_loss: 1.3917 - val_accuracy: 0.8438
# Epoch 33/50
# 8/8 [==============================] - 1s 144ms/step - loss: 3.4752e-06 - accuracy: 1.0000 - val_loss: 1.3963 - val_accuracy: 0.8438
# Epoch 34/50
# 8/8 [==============================] - 1s 144ms/step - loss: 1.4062e-05 - accuracy: 1.0000 - val_loss: 1.3917 - val_accuracy: 0.8438
# Epoch 35/50
# 8/8 [==============================] - 1s 145ms/step - loss: 1.4148e-04 - accuracy: 1.0000 - val_loss: 1.3039 - val_accuracy: 0.8438
# Epoch 36/50
# 8/8 [==============================] - 1s 146ms/step - loss: 1.0792e-05 - accuracy: 1.0000 - val_loss: 1.2205 - val_accuracy: 0.8750
# Epoch 37/50
# 8/8 [==============================] - 1s 144ms/step - loss: 1.8524e-05 - accuracy: 1.0000 - val_loss: 1.2027 - val_accuracy: 0.9062
# Epoch 38/50
# 8/8 [==============================] - 1s 144ms/step - loss: 2.4353e-05 - accuracy: 1.0000 - val_loss: 1.2057 - val_accuracy: 0.9062
# Epoch 39/50
# 8/8 [==============================] - 1s 144ms/step - loss: 4.8529e-06 - accuracy: 1.0000 - val_loss: 1.2152 - val_accuracy: 0.9062
# Epoch 40/50
# 8/8 [==============================] - 1s 144ms/step - loss: 1.0469e-04 - accuracy: 1.0000 - val_loss: 1.2558 - val_accuracy: 0.8750
# Epoch 41/50
# 8/8 [==============================] - 1s 144ms/step - loss: 3.0911e-05 - accuracy: 1.0000 - val_loss: 1.2540 - val_accuracy: 0.8750
# Epoch 42/50
# 8/8 [==============================] - 1s 144ms/step - loss: 4.7867e-05 - accuracy: 1.0000 - val_loss: 1.2594 - val_accuracy: 0.8750
# Epoch 43/50
# 8/8 [==============================] - 1s 144ms/step - loss: 1.1183e-05 - accuracy: 1.0000 - val_loss: 1.2758 - val_accuracy: 0.8750
# Epoch 44/50
# 8/8 [==============================] - 1s 144ms/step - loss: 1.4101e-04 - accuracy: 1.0000 - val_loss: 1.2211 - val_accuracy: 0.9062
# Epoch 45/50
# 8/8 [==============================] - 1s 143ms/step - loss: 2.1619e-06 - accuracy: 1.0000 - val_loss: 1.2002 - val_accuracy: 0.9062
# Epoch 46/50
# 8/8 [==============================] - 1s 144ms/step - loss: 1.6609e-06 - accuracy: 1.0000 - val_loss: 1.1911 - val_accuracy: 0.9062
# Epoch 47/50
# 8/8 [==============================] - 1s 144ms/step - loss: 3.3870e-06 - accuracy: 1.0000 - val_loss: 1.1913 - val_accuracy: 0.9062
# Epoch 48/50
# 8/8 [==============================] - 1s 144ms/step - loss: 1.0649e-04 - accuracy: 1.0000 - val_loss: 1.3050 - val_accuracy: 0.8438
# Epoch 49/50
# 8/8 [==============================] - 1s 144ms/step - loss: 3.6186e-06 - accuracy: 1.0000 - val_loss: 1.4588 - val_accuracy: 0.8438
# Epoch 50/50
# 8/8 [==============================] - 1s 144ms/step - loss: 4.3291e-06 - accuracy: 1.0000 - val_loss: 1.5279 - val_accuracy: 0.8438
# Epoch 1/50
# 8/8 [==============================] - 2s 163ms/step - loss: 0.7022 - accuracy: 0.5591 - val_loss: 0.5237 - val_accuracy: 0.7500
# Epoch 2/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.6280 - accuracy: 0.7480 - val_loss: 0.5133 - val_accuracy: 0.8125
# Epoch 3/50
# 8/8 [==============================] - 1s 147ms/step - loss: 0.3772 - accuracy: 0.8346 - val_loss: 0.2674 - val_accuracy: 0.9062
# Epoch 4/50
# 8/8 [==============================] - 1s 147ms/step - loss: 0.6101 - accuracy: 0.7717 - val_loss: 0.2996 - val_accuracy: 0.8750
# Epoch 5/50
# 8/8 [==============================] - 1s 146ms/step - loss: 0.5410 - accuracy: 0.6929 - val_loss: 0.5011 - val_accuracy: 0.8438
# Epoch 6/50
# 8/8 [==============================] - 1s 147ms/step - loss: 0.3968 - accuracy: 0.8031 - val_loss: 0.3508 - val_accuracy: 0.9062
# Epoch 7/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.4126 - accuracy: 0.8346 - val_loss: 0.2853 - val_accuracy: 0.9375
# Epoch 8/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.4254 - accuracy: 0.7953 - val_loss: 0.4571 - val_accuracy: 0.7188
# Epoch 9/50
# 8/8 [==============================] - 1s 150ms/step - loss: 0.2834 - accuracy: 0.8976 - val_loss: 0.2894 - val_accuracy: 0.8750
# Epoch 10/50
# 8/8 [==============================] - 1s 149ms/step - loss: 0.1566 - accuracy: 0.9370 - val_loss: 0.1281 - val_accuracy: 0.9688
# Epoch 11/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.
50
# 8/8 [==============================] - 1s 149ms/step - loss: 0.0546 - accuracy: 0.9764 - val_loss: 0.2568 - val_accuracy: 0.9062
# Epoch 42/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0267 - accuracy: 0.9921 - val_loss: 0.3833 - val_accuracy: 0.9062
# Epoch 43/50
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0352 - accuracy: 0.9843 - val_loss: 0.6187 - val_accuracy: 0.8750
# Epoch 44/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0787 - accuracy: 0.9685 - val_loss: 0.1576 - val_accuracy: 0.9375
# Epoch 45/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1101 - accuracy: 0.9606 - val_loss: 0.2868 - val_accuracy: 0.8750
# Epoch 46/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.8750
# Epoch 47/50
# 8/8 [==============================] - 1s 149ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9062
# Epoch 48/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.3398 - val_accuracy: 0.9062
# Epoch 49/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2492 - val_accuracy: 0.9375
# Epoch 50/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0100 - accuracy: 0.9921 - val_loss: 0.2961 - val_accuracy: 0.9375
# Epoch 1/50
# 8/8 [==============================] - 2s 166ms/step - loss: 0.7807 - accuracy: 0.5197 - val_loss: 0.7028 - val_accuracy: 0.4375
# Epoch 2/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.7106 - accuracy: 0.4567 - val_loss: 0.6830 - val_accuracy: 0.6562
# Epoch 3/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.7205 - accuracy: 0.4646 - val_loss: 0.6832 - val_accuracy: 0.5625
# Epoch 4/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.6880 - accuracy: 0.5591 - val_loss: 0.6883 - val_accuracy: 0.5000
# Epoch 5/50
# 8/8 [==============================] - 1s 147ms/step - loss: 0.6867 - accuracy: 0.5748 - val_loss: 0.6618 - val_accuracy: 0.6562
# Epoch 6/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.6697 - accuracy: 0.6063 - val_loss: 0.5786 - val_accuracy: 0.8125
# Epoch 7/50
# 8/8 [==============================] - 1s 147ms/step - loss: 0.6395 - accuracy: 0.5984 - val_loss: 0.6253 - val_accuracy: 0.5938
# Epoch 8/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.5177 - accuracy: 0.6929 - val_loss: 0.5794 - val_accuracy: 0.8125
# Epoch 9/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.5721 - accuracy: 0.7402 - val_loss: 0.6304 - val_accuracy: 0.6562
# Epoch 10/50
# 8/8 [==============================] - 1s 147ms/step - loss: 0.5652 - accuracy: 0.6693 - val_loss: 0.5542 - val_accuracy: 0.6875
# Epoch 11/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.4340 - accuracy: 0.8110 - val_loss: 0.5124 - val_accuracy: 0.7500
# Epoch 12/50
# 8/8 [==============================] - 1s 149ms/step - loss: 0.4145 - accuracy: 0.8189 - val_loss: 0.6058 - val_accuracy: 0.6250
# Epoch 13/50
# 8/8 [==============================] - 1s 149ms/step - loss: 0.5471 - accuracy: 0.7087 - val_loss: 0.4098 - val_accuracy: 0.8438
# Epoch 14/50
# 8/8 [==============================] - 1s 150ms/step - loss: 0.3963 - accuracy: 0.8346 - val_loss: 0.3956 - val_accuracy: 0.8125
# Epoch 15/50
# 8/8 [==============================] - 1s 149ms/step - loss: 0.4095 - accuracy: 0.7874 - val_loss: 0.4674 - val_accuracy: 0.7500
# Epoch 16/50
# 8/8 [==============================] - 1s 149ms/step - loss: 0.3839 - accuracy: 0.8346 - val_loss: 0.3708 - val_accuracy: 0.8438
# Epoch 17/50
# 8/8 [==============================] - 1s 149ms/step - loss: 0.3305 - accuracy: 0.8504 - val_loss: 0.3882 - val_accuracy: 0.8438
# Epoch 18/50
# 8/8 [==============================] - 1s 149ms/step - loss: 0.1831 - accuracy: 0.9370 - val_loss: 0.4728 - val_accuracy: 0.8438
# Epoch 19/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1973 - accuracy: 0.9449 - val_loss: 0.7905 - val_accuracy: 0.8438
# Epoch 20/50
# 8/8 [==============================] - 1s 147ms/step - loss: 0.7578 - accuracy: 0.7480 - val_loss: 0.7042 - val_accuracy: 0.7500
# Epoch 21/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0
# 8/8 [==============================] - 1s 159ms/step - loss: 0.2338 - accuracy: 0.9528 - val_loss: 1.9378 - val_accuracy: 0.8125
# Epoch 39/50
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0321 - accuracy: 0.9921 - val_loss: 1.7579 - val_accuracy: 0.8750
# Epoch 40/50
# 8/8 [==============================] - 1s 158ms/step - loss: 0.0403 - accuracy: 0.9843 - val_loss: 1.8687 - val_accuracy: 0.8438
# Epoch 41/50
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 1.4057 - val_accuracy: 0.7812
# Epoch 42/50
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.3710 - val_accuracy: 0.8438
# Epoch 43/50
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.6607 - val_accuracy: 0.8438
# Epoch 44/50
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.9517 - val_accuracy: 0.8750
# Epoch 45/50
# 8/8 [==============================] - 1s 160ms/step - loss: 8.8748e-04 - accuracy: 1.0000 - val_loss: 2.2599 - val_accuracy: 0.8750
# Epoch 46/50
# 8/8 [==============================] - 1s 157ms/step - loss: 6.2330e-04 - accuracy: 1.0000 - val_loss: 2.4895 - val_accuracy: 0.8750
# Epoch 47/50
# 8/8 [==============================] - 1s 157ms/step - loss: 5.4439e-04 - accuracy: 1.0000 - val_loss: 2.7858 - val_accuracy: 0.8750
# Epoch 48/50
# 8/8 [==============================] - 1s 161ms/step - loss: 2.8917e-04 - accuracy: 1.0000 - val_loss: 3.1431 - val_accuracy: 0.8438
# Epoch 49/50
# 8/8 [==============================] - 1s 160ms/step - loss: 2.9477e-05 - accuracy: 1.0000 - val_loss: 3.3084 - val_accuracy: 0.8438
# Epoch 50/50
# 8/8 [==============================] - 1s 159ms/step - loss: 7.2707e-05 - accuracy: 1.0000 - val_loss: 3.4651 - val_accuracy: 0.8438
# Epoch 1/50
# 8/8 [==============================] - 5s 208ms/step - loss: 0.8409 - accuracy: 0.7120 - val_loss: 2.0880 - val_accuracy: 0.4375
# Epoch 2/50
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0499 - accuracy: 0.9760 - val_loss: 7.8016 - val_accuracy: 0.4375
# Epoch 3/50
# 8/8 [==============================] - 1s 124ms/step - loss: 0.0674 - accuracy: 0.9840 - val_loss: 11.2823 - val_accuracy: 0.4375
# Epoch 4/50
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 10.1437 - val_accuracy: 0.4375
# Epoch 5/50
# 8/8 [==============================] - 1s 125ms/step - loss: 0.1275 - accuracy: 0.9600 - val_loss: 13.8111 - val_accuracy: 0.4375
# Epoch 6/50
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 17.7980 - val_accuracy: 0.4375
# Epoch 7/50
# 8/8 [==============================] - 1s 125ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 13.2479 - val_accuracy: 0.4375
# Epoch 8/50
# 8/8 [==============================] - 1s 125ms/step - loss: 8.7749e-04 - accuracy: 1.0000 - val_loss: 10.3492 - val_accuracy: 0.4375
# Epoch 9/50
# 8/8 [==============================] - 1s 127ms/step - loss: 4.3325e-04 - accuracy: 1.0000 - val_loss: 9.8320 - val_accuracy: 0.4375
# Epoch 10/50
# 8/8 [==============================] - 1s 127ms/step - loss: 4.6470e-04 - accuracy: 1.0000 - val_loss: 11.9720 - val_accuracy: 0.4375
# Epoch 11/50
# 8/8 [==============================] - 1s 127ms/step - loss: 4.0956e-04 - accuracy: 1.0000 - val_loss: 12.8971 - val_accuracy: 0.4375
# Epoch 12/50
# 8/8 [==============================] - 1s 127ms/step - loss: 1.6538e-04 - accuracy: 1.0000 - val_loss: 13.0781 - val_accuracy: 0.4375
# Epoch 13/50
# 8/8 [==============================] - 1s 126ms/step - loss: 1.2709e-04 - accuracy: 1.0000 - val_loss: 14.1869 - val_accuracy: 0.4375
# Epoch 14/50
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss:
50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0215 - accuracy: 0.9840 - val_loss: 75.9654 - val_accuracy: 0.4375
# Epoch 36/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0156 - accuracy: 0.9920 - val_loss: 169.6051 - val_accuracy: 0.4375
# Epoch 37/50
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0694 - accuracy: 0.9840 - val_loss: 84.3253 - val_accuracy: 0.4375
# Epoch 38/50
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0211 - accuracy: 0.9920 - val_loss: 39.2899 - val_accuracy: 0.4375
# Epoch 39/50
# 8/8 [==============================] - 1s 129ms/step - loss: 9.9813e-04 - accuracy: 1.0000 - val_loss: 33.2356 - val_accuracy: 0.4375
# Epoch 40/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0074 - accuracy: 0.9920 - val_loss: 47.9261 - val_accuracy: 0.4375
# Epoch 41/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0504 - accuracy: 0.9920 - val_loss: 58.9933 - val_accuracy: 0.4375
# Epoch 42/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0570 - accuracy: 0.9840 - val_loss: 11.3310 - val_accuracy: 0.4375
# Epoch 43/50
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 82.4524 - val_accuracy: 0.4375
# Epoch 44/50
# 8/8 [==============================] - 1s 131ms/step - loss: 5.4614e-04 - accuracy: 1.0000 - val_loss: 115.6306 - val_accuracy: 0.4375
# Epoch 45/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0285 - accuracy: 0.9840 - val_loss: 60.9124 - val_accuracy: 0.4375
# Epoch 46/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0631 - accuracy: 0.9920 - val_loss: 113.6976 - val_accuracy: 0.4375
# Epoch 47/50
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 131.5659 - val_accuracy: 0.4375
# Epoch 48/50
# 8/8 [==============================] - 1s 127ms/step - loss: 3.3734e-04 - accuracy: 1.0000 - val_loss: 117.5171 - val_accuracy: 0.4375
# Epoch 49/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 115.3848 - val_accuracy: 0.4375
# Epoch 50/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0794 - accuracy: 0.9920 - val_loss: 111.3054 - val_accuracy: 0.4375
# c:\Users\andre\anaconda3\envs\TFenv\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in longlong_scalars
# Epoch 1/50
# 8/8 [==============================] - 5s 207ms/step - loss: 0.8779 - accuracy: 0.7165 - val_loss: 1.4170 - val_accuracy: 0.4375
# Epoch 2/50
# 8/8 [==============================] - 1s 125ms/step - loss: 0.4291 - accuracy: 0.9449 - val_loss: 2.3536 - val_accuracy: 0.4375
# Epoch 3/50
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0259 - accuracy: 0.9921 - val_loss: 1.9073 - val_accuracy: 0.4375
# Epoch 4/50
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0510 - accuracy: 0.9685 - val_loss: 3.0946 - val_accuracy: 0.4375
# Epoch 5/50
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0516 - accuracy: 0.9843 - val_loss: 2.4958 - val_accuracy: 0.4375
# Epoch 6/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0328 - accuracy: 0.9843 - val_loss: 4.1369 - val_accuracy: 0.4375
# Epoch 7/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.8995 - val_accuracy: 0.4375
# Epoch 8/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.7005 - val_accuracy: 0.4375
# Epoch 9/50
# 8/8 [==============================] - 1s 127ms/step - loss: 8.8949e-04 - accuracy: 1.0000 - val_loss: 3.7874 - val_accuracy: 0.4375
# Epoch 10/50
# 8/8 [==============================] - 1s 128ms/step - loss: 7.6098e-05 - accuracy: 1.0000 - val_loss: 3.9168 - val_accuracy: 0.4375
# Epoch 11/50
# 8/8 [==============================] - 1s 129ms/step - loss: 2.9607e-04 - accuracy: 1.0000 - val_loss: 4.0340 - val_accuracy: 0.4375
# Epoch 12/50
# 8/8 [==============================] - 1s 128ms/step - loss: 8.9908e-04 - accuracy: 1.0000 - val_loss: 4.4016 - val_accuracy: 0.4375
# Epoch 13/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 4.1090 - val_accuracy: 0.4375
# Epoch 14/50
# 8/8 [==============================] - 1s 128ms/step - loss: 1.1211e-05 - accuracy: 1.0000 - val_loss: 3.8696 - val_accuracy: 0.4375
# Epoch 15/50
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 3.9485 - val_accuracy: 0.4375
# Epoch 16/50
# 8/8 [==============================] - 1s 129ms/step - loss: 4.7959e-05 - accuracy: 1.0000 - val_loss: 3.9850 - val_accuracy: 0.4375
# Epoch 17/50
# 8/8 [==============================] - 1s 129ms/step - loss: 5.2398e-06 - accuracy: 1.0000 - val_loss: 4.0665 - val_accuracy: 0.4375
# Epoch 18/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0079 - accuracy: 0.9921 - val_loss: 3.9998 - val_accuracy: 0.4375
# Epoch 19/50
# 8/8 [==============================] - 1s 128ms/step - loss: 6.7833e-06 - accuracy: 1.0000 - val_loss: 4.1480 - val_accuracy: 0.4375
# Epoch 20/50
# 8/8 [==============================] - 1s 131ms/step - loss: 2.4951e-04 - accuracy: 1.0000 - val_loss: 4.5092 - val_accuracy: 0.4375
# Epoch 21/50
# 8/8 [==============================] - 1s 131ms/step - loss: 2.3927e-04 - accuracy: 1.0000 - val_loss: 5.2691 - val_accuracy: 0.4375
# Epoch 22/50
# 8/8 [==============================] - 1s 130ms/step - loss: 7.8285e-05 - accuracy: 1.0000 - val_loss: 6.2872 - val_accuracy: 0.4375
# Epoch 23/50
# 8/8 [==============================] - 1s 131ms/step - loss: 9.4327e-05 - accuracy: 1.0000 - val_loss: 7.2708 - val_accuracy: 0.4375
# Epoch 24/50
# 8/8 [==============================] - 1s 131ms/step - loss: 5.7547e-05 - accuracy: 1.0000 - val_loss: 7.7172 - val_accuracy: 0.4375
# Epoch 25/50
# 8/8 [==============================] - 1s 129ms/step - loss: 3.9469e-05 - accuracy: 1.0000 - val_loss: 8.0035 - val_accuracy: 0.4375
# Epoch 26/50
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 4.3703 - val_accuracy: 0.4375
# Epoch 27/50
# 8/8 [==============================] - 1s 129ms/step - loss: 2.9557e-05 - accuracy: 1.0000 - val_loss: 2.3761 - val_accuracy: 0.4375
# Epoch 28/50
# 8/8 [==============================] - 1s 129ms/step - loss: 3.3339e-06 - accuracy: 1.0000 - val_loss: 1.5114 - val_accuracy: 0.4375
# Epoch 29/50
# 8/8 [==============================] - 1s 128ms/step - loss: 4.4757e-05 - accuracy: 1.0000 - val_loss: 1.2813 - val_accuracy: 0.4375
# Epoch 30/50
# 8/8 [==============================] - 1s 129ms/step - loss: 1.2713e-05 - accuracy: 1.0000 - val_loss: 1.2841 - val_accuracy: 0.4375
# Epoch 31/50
# 8/8 [==============================] - 1s 129ms/step - loss: 5.5210e-04 - accuracy: 1.0000 - val_loss: 1.8017 - val_accuracy: 0.4375
# Epoch 32/50
# 8/8 [==============================] - 1s 129ms/step - loss: 8.3389e-06 - accuracy: 1.0000 - val_loss: 2.2577 - val_accuracy: 0.4375
# Epoch 33/50
# 8/8 [==============================] - 1s 129ms/step - loss: 1.4134e-05 - accuracy: 1.0000 - val_loss: 2.7406 - val_accuracy: 0.4375
# Epoch 34/50
# 8/8 [==============================] - 1s 129ms/step - loss: 7.0988e-04 - accuracy: 1.0000 - val_loss: 3.3134 - val_accuracy: 0.4375
# Epoch 35/50
# 8/8 [==============================] - 1s 129ms/step - loss: 5.0135e-07 - accuracy: 1.0000 - val_loss: 4.0020 - val_accuracy: 0.4375
# Epoch 36/50
# 8/8 [==============================] - 1s 138ms/step - loss: 2.0692e-05 - accuracy: 1.0000 - val_loss: 4.5324 - val_accuracy: 0.4375
# Epoch 37/50
# 8/8 [==============================] - 1s 129ms/step - loss: 1.7289e-05 - accuracy: 1.0000 - val_loss: 4.8974 - val_accuracy: 0.4375
# Epoch 38/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 20.2193 - val_accuracy: 0.4375
# Epoch 39/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0219 - accuracy: 0.9921 - val_loss: 3.6090 - val_accuracy: 0.4375
# Epoch 40/50
# 8/8 [==============================] - 1s 128ms/step - loss: 3.9451e-04 - accuracy: 1.0000 - val_loss: 13.2832 - val_accuracy: 0.5625
# Epoch 41/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0135 - accuracy: 0.9921 - val_loss: 7.6203 - val_accuracy: 0.5625
# Epoch 42/50
# 8/8 [==============================] - 1s 129ms/step - loss: 4.1892e-04 - accuracy: 1.0000 - val_loss: 0.6310 - val_accuracy: 0.6250
# Epoch 43/50
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0211 - accuracy: 0.9921 - val_loss: 0.7565 - val_accuracy: 0.5625
# Epoch 44/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0279 - accuracy: 0.9843 - val_loss: 0.8159 - val_accuracy: 0.5312
# Epoch 45/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0446 - accuracy: 0.9921 - val_loss: 5.0294 - val_accuracy: 0.4375
# Epoch 46/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0370 - accuracy: 0.9843 - val_loss: 7.2765 - val_accuracy: 0.4375
# Epoch 47/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.2510 - accuracy: 0.9528 - val_loss: 1.2237 - val_accuracy: 0.4375
# Epoch 48/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0591 - accuracy: 0.9685 - val_loss: 3.2188 - val_accuracy: 0.5625
# Epoch 49/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.1609 - accuracy: 0.9764 - val_loss: 1.5304 - val_accuracy: 0.4375
# Epoch 50/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.1308 - accuracy: 0.9843 - val_loss: 3.5898 - val_accuracy: 0.4375
# c:\Users\andre\anaconda3\envs\TFenv\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in longlong_scalars
# Epoch 1/50
# 8/8 [==============================] - 5s 205ms/step - loss: 1.6161 - accuracy: 0.5984 - val_loss: 1.5352 - val_accuracy: 0.4375
# Epoch 2/50
# 8/8 [==============================] - 1s 125ms/step - loss: 0.1543 - accuracy: 0.9370 - val_loss: 1.1313 - val_accuracy: 0.4375
# Epoch 3/50
# 8/8 [==============================] - 1s 125ms/step - loss: 0.1796 - accuracy: 0.9843 - val_loss: 0.8647 - val_accuracy: 0.4375
# Epoch 4/50
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0156 - accuracy: 0.9921 - val_loss: 1.0131 - val_accuracy: 0.4375
# Epoch 5/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.1910 - val_accuracy: 0.4375
# Epoch 6/50
# 8/8 [==============================] - 1s 126ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.2271 - val_accuracy: 0.4375
# Epoch 7/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.1338 - val_accuracy: 0.4375
# Epoch 8/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0095 - accuracy: 0.9921 - val_loss: 0.7340 - val_accuracy: 0.4375
# Epoch 9/50
# 8/8 [==============================] - 1s 127ms/step - loss: 7.5496e-04 - accuracy: 1.0000 - val_loss: 0.7335 - val_accuracy: 0.5625
# Epoch 10/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0137 - accuracy: 0.9921 - val_loss: 1.0264 - val_accuracy: 0.4375
# Epoch 11/50
# 8/8 [==============================] - 1s 129ms/step - loss: 6.4076e-04 - accuracy: 1.0000 - val_loss: 1.6337 - val_accuracy: 0.4375
# Epoch 12/50
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.9210 - val_accuracy: 0.4375
# Epoch 13/50
# 8/8 [==============================] - 1s 131ms/step - loss: 8.8886e-04 - accuracy: 1.0000 - val_loss: 1.9462 - val_accuracy: 0.4375
# Epoch 14/50
# 8/8 [==============================] - 1s 128ms/step - loss: 1.8464e-04 - accuracy: 1.0000 - val_loss: 1.9412 - val_accuracy: 0.4375
# Epoch 15/50
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0089 - accuracy: 0.9921 - val_loss: 1.8539 - val_accuracy: 0.4375
# Epoch 16/50
# 8/8 [==============================] - 1s 128ms/step - loss: 6.1994e-04 - accuracy: 1.0000 - val_loss: 1.9300 - val_accuracy: 0.4375
# Epoch 17/50
# 8/8 [==============================] - 1s 129ms/step - loss: 3.8899e-05 - accuracy: 1.0000 - val_loss: 1.9804 - val_accuracy: 0.4375
# Epoch 18/50
# 8/8 [==============================] - 1s 129ms/step - loss: 2.0059e-04 - accuracy: 1.0000 - val_loss: 1.9994 - val_accuracy: 0.4375
# Epoch 19/50
# 8/8 [==============================] - 1s 128ms/step - loss: 3.2455e-05 - accuracy: 1.0000 - val_loss: 1.9781 - val_accuracy: 0.4375
# Epoch 20/50
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.0352 - val_accuracy: 0.4375
# Epoch 21/50
# 8/8 [==============================] - 1s 130ms/step - loss: 4.7788e-04 - accuracy: 1.0000 - val_loss: 2.3723 - val_accuracy: 0.4375
# Epoch 22/50
# 8/8 [==============================] - 1s 130ms/step - loss: 1.0239e-04 - accuracy: 1.0000 - val_loss: 2.4565 - val_accuracy: 0.4375
# Epoch 23/50
# 8/8 [==============================] - 1s 129ms/step - loss: 2.0446e-04 - accuracy: 1.0000 - val_loss: 2.4620 - val_accuracy: 0.4375
# Epoch 24/50
# 8/8 [==============================] - 1s 129ms/step - loss: 4.4053e-04 - accuracy: 1.0000 - val_loss: 2.4711 - val_accuracy: 0.4375
# Epoch 25/50
# 8/8 [==============================] - 1s 130ms/step - loss: 1.1208e-04 - accuracy: 1.0000 - val_loss: 2.3381 - val_accuracy: 0.4375
# Epoch 26/50
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0059 - accuracy: 0.9921 - val_loss: 1.7807 - val_accuracy: 0.5625
# Epoch 27/50
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0107 - accuracy: 0.9921 - val_loss: 6.3513 - val_accuracy: 0.5625
# Epoch 28/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 10.0196 - val_accuracy: 0.5625
# Epoch 29/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 9.2227 - val_accuracy: 0.5625
# Epoch 30/50
# 8/8 [==============================] - 1s 130ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 7.6074 - val_accuracy: 0.5625
# Epoch 31/50
# 8/8 [==============================] - 1s 130ms/step - loss: 6.2710e-04 - accuracy: 1.0000 - val_loss: 6.5754 - val_accuracy: 0.5625
# Epoch 32/50
# 8/8 [==============================] - 1s 129ms/step - loss: 3.1110e-05 - accuracy: 1.0000 - val_loss: 6.0507 - val_accuracy: 0.5625
# Epoch 33/50
# 8/8 [==============================] - 1s 130ms/step - loss: 3.7930e-04 - accuracy: 1.0000 - val_loss: 5.8703 - val_accuracy: 0.5625
# Epoch 34/50
# 8/8 [==============================] - 1s 130ms/step - loss: 1.1150e-04 - accuracy: 1.0000 - val_loss: 5.8728 - val_accuracy: 0.5625
# Epoch 35/50
# 8/8 [==============================] - 1s 133ms/step - loss: 2.2836e-05 - accuracy: 1.0000 - val_loss: 5.8954 - val_accuracy: 0.5625
# Epoch 36/50
# ...
# Epoch 3/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0775 - accuracy: 0.9606 - val_loss: 0.6930 - val_accuracy: 0.5625
# Epoch 4/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.1768 - accuracy: 0.9370 - val_loss: 0.7484 - val_accuracy: 0.4375
# Epoch 5/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0524 - accuracy: 0.9843 - val_loss: 0.8307 - val_accuracy: 0.4375
# Epoch 6/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0460 - accuracy: 0.9843 - val_loss: 0.7939 - val_accuracy: 0.4375
# Epoch 7/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.7390 - val_accuracy: 0.4375
# Epoch 8/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.7011 - val_accuracy: 0.4375
# Epoch 9/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.6835 - val_accuracy: 0.5625
# Epoch 10/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0426 - accuracy: 0.9843 - val_loss: 0.6854 - val_accuracy: 0.5625
# Epoch 11/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.6872 - val_accuracy: 0.5625
# Epoch 12/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.6834 - val_accuracy: 0.5625
# Epoch 13/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.6791 - val_accuracy: 0.5625
# Epoch 14/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.6786 - val_accuracy: 0.5312
# Epoch 15/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.6901 - val_accuracy: 0.5625
# Epoch 16/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6999 - val_accuracy: 0.4375
# Epoch 17/50
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.6989 - val_accuracy: 0.4688
# Epoch 18/50
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.6893 - val_accuracy: 0.5625
# Epoch 19/50
# 8/8 [==============================] - 1s 143ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.6835 - val_accuracy: 0.5312
# Epoch 20/50
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.6844 - val_accuracy: 0.5312
# Epoch 21/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.6870 - val_accuracy: 0.5625
# Epoch 22/50
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.6955 - val_accuracy: 0.5000
# Epoch 23/50
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.7126 - val_accuracy: 0.4688
# Epoch 24/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.7340 - val_accuracy: 0.4375
# Epoch 25/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.7507 - val_accuracy: 0.4375
# Epoch 26/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7715 - val_accuracy: 0.4375
# Epoch 27/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0165 - accuracy: 0.9921 - val_loss: 0.8071 - val_accuracy: 0.4375
# Epoch 28/50
# 8/8 [==============================] - 1s 137ms/step - loss: 9.5819e-04 - accuracy: 1.0000 - val_loss: 0.7580 - val_accuracy: 0.4688
# Epoch 29/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.7549 - val_accuracy: 0.4688
# Epoch 30/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.7633 - val_accuracy: 0.6250
# Epoch 31/50
# 8/8 [==============================] - 1s 140ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6907 - val_accuracy: 0.5625
# Epoch 32/50
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.7437 - val_accuracy: 0.5625
# Epoch 33/50
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.7424 - val_accuracy: 0.5312
# Epoch 34/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.8550 - val_accuracy: 0.4062
# Epoch 35/50
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.1836 - val_accuracy: 0.3438
# Epoch 36/50
# 8/8 [==============================] - 1s 133ms/step - loss: 2.4706e-04 - accuracy: 1.0000 - val_loss: 1.3940 - val_accuracy: 0.3750
# Epoch 37/50
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.3985 - val_accuracy: 0.4062
# Epoch 38/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.2696 - val_accuracy: 0.4062
# Epoch 39/50
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.0654 - val_accuracy: 0.4062
# Epoch 40/50
# 8/8 [==============================] - 1s 135ms/step - loss: 4.6944e-04 - accuracy: 1.0000 - val_loss: 1.1795 - val_accuracy: 0.4375
# Epoch 41/50
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2243 - val_accuracy: 0.3125
# Epoch 42/50
# 8/8 [==============================] - 1s 136ms/step - loss: 6.3986e-04 - accuracy: 1.0000 - val_loss: 1.1236 - val_accuracy: 0.3438
# Epoch 43/50
# 8/8 [==============================] - 1s 134ms/step - loss: 2.3920e-04 - accuracy: 1.0000 - val_loss: 1.1106 - val_accuracy: 0.3750
# Epoch 44/50
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.1914 - val_accuracy: 0.3750
# Epoch 45/50
# 8/8 [==============================] - 1s 136ms/step - loss: 2.4813e-04 - accuracy: 1.0000 - val_loss: 1.3808 - val_accuracy: 0.3438
# Epoch 46/50
# 8/8 [==============================] - 1s 136ms/step - loss: 8.4747e-04 - accuracy: 1.0000 - val_loss: 1.3828 - val_accuracy: 0.3750
# Epoch 47/50
# 8/8 [==============================] - 1s 137ms/step - loss: 8.2845e-04 - accuracy: 1.0000 - val_loss: 1.3549 - val_accuracy: 0.4688
# Epoch 48/50
# 8/8 [==============================] - 1s 137ms/step - loss: 3.1915e-04 - accuracy: 1.0000 - val_loss: 1.2701 - val_accuracy: 0.4688
# Epoch 49/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0062 - accuracy: 0.9921 - val_loss: 1.2768 - val_accuracy: 0.4062
# Epoch 50/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0162 - accuracy: 0.9921 - val_loss: 1.3616 - val_accuracy: 0.4375
# Epoch 1/50
# 8/8 [==============================] - 6s 259ms/step - loss: 0.6709 - accuracy: 0.5906 - val_loss: 0.7235 - val_accuracy: 0.5625
# Epoch 2/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.2546 - accuracy: 0.8898 - val_loss: 0.8660 - val_accuracy: 0.5625
# Epoch 3/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0756 - accuracy: 0.9685 - val_loss: 0.7147 - val_accuracy: 0.5625
# Epoch 4/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.6899 - val_accuracy: 0.5625
# Epoch 5/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.6967 - val_accuracy: 0.5625
# Epoch 6/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0209 - accuracy: 0.9921 - val_loss: 0.7071 - val_accuracy: 0.5625
# Epoch 7/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.6918 - val_accuracy: 0.5625
# Epoch 8/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.6815 - val_accuracy: 0.5625
# Epoch 9/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0081 - accuracy: 0.9921 - val_loss: 0.6844 - val_accuracy: 0.5625
# Epoch 10/50
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.6818 - val_accuracy: 0.5625
# Epoch 11/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6814 - val_accuracy: 0.5625
# Epoch 12/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0142 - accuracy: 0.9921 - val_loss: 0.6802 - val_accuracy: 0.5625
# Epoch 13/50
# 8/8 [==============================] - 1s 143ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.6844 - val_accuracy: 0.5938
# Epoch 14/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7173 - val_accuracy: 0.4375
# Epoch 15/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.7440 - val_accuracy: 0.4375
# Epoch 16/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.7624 - val_accuracy: 0.4375
# Epoch 17/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.7472 - val_accuracy: 0.4375
# Epoch 18/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.7343 - val_accuracy: 0.4375
# Epoch 19/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7103 - val_accuracy: 0.5000
# Epoch 20/50
# 8/8 [==============================] - 1s 138ms/step - loss: 5.2012e-04 - accuracy: 1.0000 - val_loss: 0.6906 - val_accuracy: 0.5625
# Epoch 21/50
# 8/8 [==============================] - 1s 154ms/step - loss: 4.4780e-04 - accuracy: 1.0000 - val_loss: 0.6660 - val_accuracy: 0.5938
# Epoch 22/50
# 8/8 [==============================] - 1s 148ms/step - loss: 6.2750e-04 - accuracy: 1.0000 - val_loss: 0.6321 - val_accuracy: 0.6562
# Epoch 23/50
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.6072 - val_accuracy: 0.7188
# Epoch 24/50
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.6382 - val_accuracy: 0.6875
# Epoch 25/50
# 8/8 [==============================] - 1s 146ms/step - loss: 5.3281e-04 - accuracy: 1.0000 - val_loss: 0.6855 - val_accuracy: 0.5625
# Epoch 26/50
# 8/8 [==============================] - 1s 140ms/step - loss: 7.5204e-04 - accuracy: 1.0000 - val_loss: 0.7065 - val_accuracy: 0.5312
# Epoch 27/50
# 8/8 [==============================] - 1s 135ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.7013 - val_accuracy: 0.5938
# Epoch 28/50
# 8/8 [==============================] - 1s 140ms/step - loss: 5.4394e-04 - accuracy: 1.0000 - val_loss: 0.7247 - val_accuracy: 0.6250
# Epoch 29/50
# 8/8 [==============================] - 1s 134ms/step - loss: 6.0729e-04 - accuracy: 1.0000 - val_loss: 0.7377 - val_accuracy: 0.5625
# Epoch 30/50
# 8/8 [==============================] - 1s 139ms/step - loss: 7.9069e-04 - accuracy: 1.0000 - val_loss: 0.7567 - val_accuracy: 0.5625
# Epoch 31/50
# 8/8 [==============================] - 1s 138ms/step - loss: 8.1017e-04 - accuracy: 1.0000 - val_loss: 0.7521 - val_accuracy: 0.5312
# Epoch 32/50
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7349 - val_accuracy: 0.5312
# Epoch 33/50
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.7126 - val_accuracy: 0.5312
# Epoch 34/50
# 8/8 [==============================] - 1s 137ms/step - loss: 8.0822e-04 - accuracy: 1.0000 - val_loss: 0.6853 - val_accuracy: 0.5625
# Epoch 35/50
# 8/8 [==============================] - 1s 136ms/step - loss: 3.8800e-04 - accuracy: 1.0000 - val_loss: 0.6748 - val_accuracy: 0.5625
# Epoch 36/50
# 8/8 [==============================] - 1s 138ms/step - loss: 5.3217e-04 - accuracy: 1.0000 - val_loss: 0.6599 - val_accuracy: 0.5625
# Epoch 37/50
# 8/8 [==============================] - 1s 137ms/step - loss: 5.3524e-04 - accuracy: 1.0000 - val_loss: 0.6545 - val_accuracy: 0.5312
# Epoch 38/50
# 8/8 [==============================] - 1s 135ms/step - loss: 2.7559e-04 - accuracy: 1.0000 - val_loss: 0.6455 - val_accuracy: 0.5000
# Epoch 39/50
# 8/8 [==============================] - 1s 141ms/step - loss: 4.2712e-04 - accuracy: 1.0000 - val_loss: 0.6405 - val_accuracy: 0.5625
# Epoch 40/50
# 8/8 [==============================] - 1s 136ms/step - loss: 2.8030e-04 - accuracy: 1.0000 - val_loss: 0.6367 - val_accuracy: 0.6250
# Epoch 41/50
# 8/8 [==============================] - 1s 138ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.6412 - val_accuracy: 0.6562
# Epoch 42/50
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.6687 - val_accuracy: 0.5625
# Epoch 43/50
# 8/8 [==============================] - 1s 138ms/step - loss: 3.7315e-04 - accuracy: 1.0000 - val_loss: 0.6626 - val_accuracy: 0.5938
# Epoch 44/50
# 8/8 [==============================] - 1s 136ms/step - loss: 7.2723e-04 - accuracy: 1.0000 - val_loss: 0.6197 - val_accuracy: 0.7500
# Epoch 45/50
# 8/8 [==============================] - 1s 136ms/step - loss: 7.5229e-04 - accuracy: 1.0000 - val_loss: 0.5919 - val_accuracy: 0.7188
# Epoch 46/50
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5831 - val_accuracy: 0.7188
# Epoch 47/50
# 8/8 [==============================] - 1s 138ms/step - loss: 5.0310e-04 - accuracy: 1.0000 - val_loss: 0.5976 - val_accuracy: 0.7188
# Epoch 48/50
# 8/8 [==============================] - 1s 137ms/step - loss: 4.6582e-04 - accuracy: 1.0000 - val_loss: 0.6317 - val_accuracy: 0.6875
# Epoch 49/50
# 8/8 [==============================] - 1s 137ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.6526 - val_accuracy: 0.6562
# Epoch 50/50
# 8/8 [==============================] - 1s 136ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.6516 - val_accuracy: 0.6875
# -------    ENDOMETRI e NON_CONCEROUS   ------
#            Modelo  Acuracia  Sensibilidade  Especificidade   F-Score   AUC-ROC
# 0           VGG16     0.875       0.947368        0.809524  0.878049  0.878446
# 1        ResNet50     0.525       0.000000        1.000000  0.000000  0.500000
# 2     InceptionV3     0.875       0.789474        0.952381  0.857143  0.870927
# 3     MobileNetV2     0.875       0.894737        0.857143  0.871795  0.875940
# 4  EfficientNetB0     0.550       0.052632        1.000000  0.100000  0.526316
# -------    Clear_Cell e NON_CONCEROUS   ------
#            Modelo  Acuracia  Sensibilidade  Especificidade   F-Score   AUC-ROC
# 0           VGG16     0.825       0.789474        0.857143  0.810811  0.823308
# 1        ResNet50     0.525       0.000000        1.000000  0.000000  0.500000
# 2     InceptionV3     0.775       0.736842        0.809524  0.756757  0.773183
# 3     MobileNetV2     0.675       0.631579        0.714286  0.648649  0.672932
# 4  EfficientNetB0     0.500       1.000000        0.047619  0.655172  0.523810
# -------    Mucinous e NON_CONCEROUS   ------
#            Modelo  Acuracia  Sensibilidade  Especificidade   F-Score   AUC-ROC
# 0           VGG16     0.700       0.736842        0.666667  0.700000  0.701754
# 1        ResNet50     0.475       1.000000        0.000000  0.644068  0.500000
# 2     InceptionV3     0.650       0.315789        0.952381  0.461538  0.634085
# 3     MobileNetV2     0.650       0.263158        1.000000  0.416667  0.631579
# 4  EfficientNetB0     0.525       0.105263        0.904762  0.173913  0.505013
# -------    Serous e NON_CONCEROUS   ------
#            Modelo  Acuracia  Sensibilidade  Especificidade   F-Score   AUC-ROC
# 0           VGG16     0.850       0.842105        0.857143  0.842105  0.849624
# 1        ResNet50     0.475       1.000000        0.000000  0.644068  0.500000
# 2     InceptionV3     0.925       0.842105        1.000000  0.914286  0.921053
# 3     MobileNetV2     0.925       0.842105        1.000000  0.914286  0.921053
# 4  EfficientNetB0     0.450       0.210526        0.666667  0.266667  0.438596
